# %% [markdown]
# # Run model on fake data
#
# Here, we generate a synthetic data set for purposes of validating the model constructed in Edward.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import edward as ed
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# we'll want this function below
def softplus(x):
    return np.logaddexp(0, x)

# %%
ed.set_seed(12225)

# %% [markdown]
# The model is defined by the spike count $N_{us}$ observed when stimulus $s$ is presented to unit $u$:
#
# $$
# \begin{align}
# N &\sim \mathrm{Poisson}(e^\lambda)  \\
# \lambda_{us} &\sim \mathcal{N}(A_{u} + (B \cdot X)_{us} + (C \cdot Z)_{us}, \sigma^2) \\
# \log \sigma &\sim \mathcal{N}(-7, 1^2) \\
# Z_{ks} &\sim \mathrm{Bernoulli}(\pi_k) \\
# \pi_k &\equiv \prod_{i=1}^k \delta_k \\
# \delta_j &\sim \mathrm{Beta}(3, 1)
# \end{align}
# $$
# With $X$ an $P \times N_s$ matrix of known regressors, $Z$ a $K \times N_s$ matrix of latent binary features
# governed by an Indian Buffet Process, $A$ and $N_u$ vector of baselines, and $(\cdot)_+$ the softplus function:
# $(x)_+ = \log(1 + e^x)$.

# %% [markdown]
# In addition, we assume that $A$, $B$, and $C$ are all hierarchically distributed:
#
# $$\begin{align}
# A_u &\sim \mathcal{N}(\mu_A, \sigma^2_A) \\
# B_{up} &\sim \mathcal{N}(\mu_{Bp}, \sigma^2_{Bp}) \\
# C_{uk} &\sim \mathcal{N}(\mu_{Ck}, \sigma^2_{Ck}) \\
# \mu_A &\sim \mathcal{N}(\log 25, 0.5^2) \\
# \sigma_A &\sim \mathrm{Ga}(2, 4) \\
# \mu_{Bp} &\sim \mathcal{N}(0, 0.5^2) \\
# \sigma_{Bp} &\sim \mathrm{Ga}(2, 4) \\
# \mu_{Ck} &\sim \mathcal{N}(0, 0.5^2) \\
# \sigma_{Ck} &\sim \mathrm{Ga}(2, 4)
# \end{align}$$

# %% [markdown]
# # Define constants

# %%
# basic constants
Nrep = 40  # number of observations per unit per stim
NB = 1000  # number of trials in minibatch
NU = 50  # number of units
NS = 50  # number of stims
P = 3  # number of specified regressors
K = 4  # number of latents

# %% [markdown]
# # Make neural response coefficients

# %%
dA = np.log(softplus(25 + 5 * np.random.randn(NU)))  # baseline
dB = np.log(np.array([0.75, 1.2, 1.5]) + 0.1 * np.random.randn(NU, P))  # regressor effects
dC = np.log(np.array([0.25, 0.55, 1.4, 2.2])[np.newaxis, :] + 0.1 * np.random.randn(NU, K))  # latent effects

# %% [markdown]
# # Regressors and latent states

# %%
dX = 0.1 * np.random.randn(P, NS)

import scipy.stats as stats

ddelta = stats.beta.rvs(1.2, 1, size=(K,))
dpi = np.cumprod(ddelta)
print(ddelta, dpi)
dZ = stats.bernoulli.rvs(dpi[:, np.newaxis], size=(K, NS))

# plot states
plt.matshow(dZ, aspect='auto', cmap='gray');
# Out:
# [ 0.70137886  0.57732232  0.24895886  0.49916835] [ 0.70137886  0.40492167  0.10080884  0.05032058]

# %% [markdown]
# # Generate trial set

# %%
dU, dS = np.meshgrid(range(NU), range(NS))
dU = dU.ravel()
dS = dS.ravel()

# %%
dlam_mean = np.tile(dA[dU] + np.sum(dB[dU] * dX[:, dS].T, axis=1) + np.sum(dC[dU] * dZ[:, dS].T, axis=1), Nrep)

dlam = stats.norm.rvs(loc=dlam_mean, scale=0.01)

# %%
dcount = stats.poisson.rvs(np.exp(dlam))
dcount.shape
# Out:
# (100000,)

# %%
plt.hist(dlam, bins=200);

# %%
plt.hist(np.exp(dlam), bins=200);

# %%
plt.hist(dcount, bins=200);

# %% [markdown]
# # Set up data

# %%
count = dcount.copy()
Xdat = np.tile(dX[:, dS], (1, Nrep)).T
unit = np.tile(dU, Nrep)
stim = np.tile(dS, Nrep)

# %% [markdown]
# Later, we'll need to know the number of observations of each (stim, unit) pair. This is constant for this toy example, but need not be.

# %%
pairs = pd.DataFrame({'stim': stim, 'unit': unit, 'count': 1})

# %%
# count the number of occurrences of each pair
pair_counts_df_long = pairs.groupby(['stim', 'unit']).sum().reset_index()
pair_counts_df_long.head()
# Out:
#    stim  unit  count
# 0     0     0     40
# 1     0     1     40
# 2     0     2     40
# 3     0     3     40
# 4     0     4     40

# %%
pair_counts = pair_counts_df_long.pivot(values='count', index='stim', columns='unit').values

# %% [markdown]
# We'd also like to know a unique code for each *possible* (stim, unit) pair. (Some might be missing, but in this case, we still want to code that, since we'll be using these codes to sum over all observations, and the resulting matrix may have some 0 entries, but it must be dense.
#
# We will assume that units and stims are consecutively numbered.

# %%
su_codes = NU * stim + unit

# %% [markdown]
# # Run GLM to get inits
#
# Here, we run a GLM on the observed data with $A$ and $B$ included (but not $C \cdot Z$) to get a rough starting point. This takes time, but is a net win in terms of saving SGD iterations.

# %% [raw]
# import statsmodels.api as sm
# import statsmodels.formula.api as smf
# Xdf = pd.DataFrame(Xdat)
# Xdf.columns = ['X' + str(c) for c in Xdf.columns]
# dta = pd.concat([pd.DataFrame({'count': count, 'unit': unit, 'stim': stim}), Xdf], axis=1)
# formula = 'count ~ -1 + C(unit) + C(unit) * (' + '+'.join(Xdf.columns) + ')'
# mod = smf.glm(formula=formula, data=dta, family=sm.families.Poisson()).fit()

# %% [markdown]
# Now extract the model's fitted parameters into inits for $A$ and $B$

# %% [raw]
# A_init = mod.params.values[:NU].astype('float32')
# B_init = mod.params.values[NU:].reshape(P, NU).T.astype('float32')

# %% [markdown]
# # Define the model

# %% [markdown]
# ## Constants

# %%
# define some needed constants
N = Xdat.shape[0]  # number of trials

# %%
N
# Out:
# 100000

# %% [markdown]
# ## Inputs and data

# %%
X = tf.constant(Xdat.astype('float32'))
U = tf.constant(unit)
S = tf.constant(stim)
counts = tf.constant(count)
allinds = tf.constant(np.arange(N))
NSU = tf.constant(pair_counts.astype('float32'))
codes_SU = tf.constant(su_codes)

# %%
X.get_shape()
# Out:
# TensorShape([Dimension(100000), Dimension(3)])

# %% [markdown]
# Make a node that produces `NB` indices from the range $[0, N - 1]$. These are the subset of data points we want to use.

# %% [raw]
# batch_inds = tf.train.range_input_producer(N).dequeue_many(NB, name='batch_inds')
# batch_counts = tf.train.batch(tf.train.slice_input_producer([counts]), NB, name='batch_counts')

# %% [raw]
# batch_inds = tf.constant(np.arange(NB))
# batch_counts = tf.train.batch(tf.train.slice_input_producer([counts]), NB)

# %% [raw]
# batch_inds, batch_counts = tf.train.batch(tf.train.slice_input_producer([allinds, counts]), NB,
#                                           name='batches')

# %%
NB = N
batch_inds = np.arange(N)
batch_counts = counts

# %% [markdown]
# ## Generative (p) model

# %%
with tf.variable_scope("pmodel"):
    muA = ed.models.Normal(mu=np.log(25) * tf.ones(1), sigma=0.5 * tf.ones(1), name='mu_A')
    muB = ed.models.Normal(mu=tf.zeros(P), sigma=0.5 * tf.ones(P), name='mu_B')
    muC = ed.models.Normal(mu=tf.zeros(K), sigma=0.5 * tf.ones(K), name='mu_C')
    sigA = ed.models.Gamma(alpha=2. * tf.ones(1), beta=4. * tf.ones(1), name='sig_A')
    sigB = ed.models.Gamma(alpha=2. * tf.ones(P), beta=4. * tf.ones(P), name='sig_B')
    sigC = ed.models.Gamma(alpha=2. * tf.ones(K), beta=4. * tf.ones(K), name='sig_C') 

    A = ed.models.Normal(mu=tf.tile(muA, (NU,)), 
                         sigma=tf.tile(sigA, (NU,)), 
                         name='A')
    B = ed.models.Normal(mu=tf.tile(tf.expand_dims(muB, 0), (NU, 1)), 
                         sigma=tf.tile(tf.expand_dims(sigB, 0), (NU, 1)), 
                         name='B')
    C = ed.models.Normal(mu=tf.tile(tf.expand_dims(muC, 0), (NU, 1)), 
                         sigma=tf.tile(tf.expand_dims(sigC, 0), (NU, 1)), 
                         name='C')  

    a_prior = tf.ones(K)
    b_prior = tf.ones(K)
    pi = ed.models.Beta(a=a_prior, b=b_prior, name='pi')

    Z = ed.models.Bernoulli(p=tf.tile(tf.expand_dims(pi, 0), [NS, 1]), name='Z')

    sig = ed.models.Normal(mu=[-7.0], sigma=[1.], name='sig')

    lam_vars = (tf.gather(A, U) + tf.reduce_sum(tf.gather(B, U) * X, 1) + 
           tf.reduce_sum(tf.gather(C, U) * tf.gather(tf.to_float(Z), S), 1))
    lam = ed.models.Normal(mu=tf.gather(lam_vars, batch_inds), 
                           sigma=tf.exp(sig), name='lam')

    cnt = ed.models.Poisson(lam=tf.exp(lam), value=tf.ones(NB), name='cnt')

# %% [markdown]
# # Recognition (q) model

# %%
with tf.variable_scope("qmodel"):
    # population means
    q_muA = ed.models.NormalWithSoftplusSigma(mu=tf.Variable(np.log(25) * tf.ones(1)), 
                                              sigma=tf.Variable(0.5 * tf.ones(1)),
                                              name='mu_A')
    tf.scalar_summary('q_muA', tf.reduce_mean(q_muA.mean()))

    q_muB = ed.models.NormalWithSoftplusSigma(mu=tf.Variable(tf.zeros(P)), 
                                              sigma=tf.Variable(0.5 * tf.ones(P)),
                                              name='mu_B')
    tf.scalar_summary('q_muB', tf.reduce_mean(q_muB.mean()))

    q_muC = ed.models.NormalWithSoftplusSigma(mu=tf.Variable(tf.zeros(K)), 
                                              sigma=tf.Variable(0.5 * tf.ones(K)),
                                              name='mu_C')
    tf.scalar_summary('q_muC', tf.reduce_mean(q_muC.mean()))


    # population standard deviations
    q_sigA = ed.models.GammaWithSoftplusAlphaBeta(alpha=tf.Variable(2. * tf.ones(1)), 
                                                  beta=tf.Variable(4. * tf.ones(1)),
                                                  name='sig_A')
    tf.scalar_summary('q_sigA', tf.reduce_mean(q_sigA.mean()))

    q_sigB = ed.models.GammaWithSoftplusAlphaBeta(alpha=tf.Variable(2. * tf.ones(P)), 
                                                  beta=tf.Variable(4. * tf.ones(P)),
                                                  name='sig_B')
    tf.scalar_summary('q_sigB', tf.reduce_mean(q_sigB.mean()))

    q_sigC = ed.models.GammaWithSoftplusAlphaBeta(alpha=tf.Variable(2. * tf.ones(K)), 
                                                  beta=tf.Variable(4. * tf.ones(K)),
                                                  name='sig_C')
    tf.scalar_summary('q_sigC', tf.reduce_mean(q_sigC.mean()))

    
    # individual unit coefficients
    q_A = ed.models.NormalWithSoftplusSigma(mu=tf.Variable(tf.random_normal((NU,))), 
                                            sigma=tf.Variable(0.5 + tf.random_uniform((NU,))),
                                            name='A')
    tf.scalar_summary('q_A', tf.reduce_mean(q_A.mean()))

    q_B = ed.models.NormalWithSoftplusSigma(mu=tf.Variable(tf.random_normal((NU, P))), 
                                            sigma=tf.Variable(0.5 + tf.random_uniform((NU, P))),
                                            name='B')
    tf.scalar_summary('q_B', tf.reduce_mean(q_B.mean()))

    q_C = ed.models.NormalWithSoftplusSigma(mu=tf.Variable(tf.random_normal((NU, K))), 
                                            sigma=tf.Variable(0.5 + tf.random_uniform((NU, K))),
                                            name='C')
    tf.scalar_summary('q_C', tf.reduce_mean(q_C.mean()))
    
    # latent variables for each stimulus
    Zlogit = tf.Variable(-0.0 + tf.zeros((NS, K)), name='Z_logit_clip')
    tf.scalar_summary('max_Z_logit', tf.reduce_max(Zlogit))
    tf.scalar_summary('min_Z_logit', tf.reduce_min(Zlogit))
    q_Z = ed.models.BernoulliWithSigmoidP(p=Zlogit, name='Z')
    tf.scalar_summary('q_Z', tf.reduce_mean(q_Z.mean()))
    tf.scalar_summary('max_q_Z', tf.reduce_max(q_Z.mean()))
    tf.scalar_summary('min_q_Z', tf.reduce_min(q_Z.mean()))

    # latent variables for stimulus category
    a_var = tf.Variable(1. + tf.random_uniform((K,)))
    b_var = tf.Variable(1. + tf.random_uniform((K,)))
    tf.scalar_summary('max_a', tf.reduce_max(a_var))
    tf.scalar_summary('max_b', tf.reduce_max(b_var))
    tf.scalar_summary('min_a', tf.reduce_min(a_var))
    tf.scalar_summary('min_b', tf.reduce_min(b_var))
    q_pi = ed.models.Beta(a=a_var, b=b_var, name='pi')
    tf.scalar_summary('min_q_pi', tf.reduce_min(q_pi.value()))
    tf.scalar_summary('max_q_pi', tf.reduce_max(q_pi.value()))

    # log firing rates
    lam_mu = tf.Variable(2 + tf.random_normal((N,)))
    tf.scalar_summary('lam_mu_mean', tf.reduce_mean(tf.gather(lam_mu, batch_inds)))
    lam_sig = tf.Variable(3 * tf.random_uniform((N,)) + 2)
    q_lam = ed.models.NormalWithSoftplusSigma(mu=tf.gather(lam_mu, batch_inds),
                                              sigma=tf.gather(lam_sig, batch_inds),
                                              name='lam')

    q_sig = ed.models.NormalWithSoftplusSigma(mu=tf.Variable(-0.1 * tf.random_uniform((1,))),
                                              sigma=tf.Variable(tf.random_uniform((1,))),
                                              name='sig')

# %% [markdown]
# # ELBO

# %%
def make_ELBO(latent_vars, data, scale):
    from edward.util import copy
    p_log_prob = 0.0
    q_log_prob = 0.0
    z_sample = {}
    scope = "ELBO"

    for z, qz in latent_vars.items():
        # Copy q(z) to obtain new set of posterior samples.
        qz_copy = copy(qz, scope=scope)
        z_sample[z] = qz_copy.value()
        z_log_prob = tf.reduce_sum(qz.log_prob(tf.stop_gradient(z_sample[z])))
        if z in scale:
            z_log_prob *= scale[z]

        q_log_prob += z_log_prob

    dict_swap = z_sample
    for x, qx in data.items():
        if isinstance(x, ed.RandomVariable):
            if isinstance(qx, ed.RandomVariable):
                qx_copy = copy(qx, scope=scope)
                dict_swap[x] = qx_copy.value()
            else:
                dict_swap[x] = qx

            for z in latent_vars.keys():
                z_copy = copy(z, dict_swap, scope=scope)
                z_log_prob = tf.reduce_sum(z_copy.log_prob(dict_swap[z]))
                if z in scale:
                    z_log_prob *= scale[z]

                p_log_prob += z_log_prob

            for x in data.keys():
                if isinstance(x, ed.RandomVariable):
                    x_copy = copy(x, dict_swap, scope=scope)
                    x_log_prob = tf.reduce_sum(x_copy.log_prob(dict_swap[x]))
                if x in scale:
                    x_log_prob *= scale[x]

                p_log_prob += x_log_prob

    return tf.reduce_mean(p_log_prob - q_log_prob)

# %%
elbo = make_ELBO({A: q_A, B: q_B, C: q_C, 
                  muA: q_muA, muB: q_muB, muC: q_muC,
                  sigA: q_sigA, sigB: q_sigB, sigC: q_sigC,
                  Z: q_Z, sig: q_sig, pi: q_pi, lam: q_lam}, 
                 {cnt: tf.cast(batch_counts, 'float32')}, 
                 {lam: N/NB, cnt: N/NB})

tf.scalar_summary('ELBO', elbo)
# Out:
# <tf.Tensor 'ScalarSummary:0' shape=() dtype=string>

# %% [markdown]
# # Do variational inference

# %% [markdown]
# Given $z_{sk} \sim \mathrm{Ber}(\pi_k)$ and $\log \Lambda \equiv \lambda_{su} \sim \mathcal{N}(A_u + (B \cdot X)_{su} + (C \cdot Z)_{su}, \sigma^2)$, we can calculate closed-form updates for $Z$. However, above, we have flattened $\lambda$ into a single vector for each trial, with vectors $S$ and $U$ listing the stimulus and unit corresponding to each observation.
#
# Collecting the pieces proportional to $z_{sk}$ in the ELBO (prior to expectations wrt $q$), we have:
#
# $$
# \sum_{sk} z_{sk}\left[
# \log \frac{\pi_k}{1 - \pi_k} -\frac{1}{2\sigma^2}\sum_{u,j=1\ldots N_{su}} \left(
# C^2_{ku} - 2C_{ku}(\lambda^{(j)}_{su} - A_u - (B\cdot X)_{su} )
# \right)
# \right]
# $$
# where the derivation expands the square in the log of the normal distribution and makes use of the fact that $z_{sk} \in \{ 0, 1\} \Rightarrow z_{sk}^2 = z_{sk}$. In addition, we have let $N_{su}$ be the number of observations of stimulus $s$ by unit $u$, indexed by $j$.

# %%
def update_z():
    # update binary feature matrix based on exact conjugate update
    with tf.variable_scope("update_z"):
        # logit piece
        pi_val = q_pi.value()
        logit_pi = tf.log(pi_val) - tf.log(1. - pi_val)
        
        # C^2 piece
        C = q_C.value()  # NU x K
        quad_piece = tf.matmul(NSU, tf.square(C), name='quadratic_piece')
        
        # sample log firing rate values
        lam_val = q_lam.value()  
        
        # now get \lam_{su} summed over observations
        lam_su_flat = tf.unsorted_segment_sum(lam_val, codes_SU, NS * NU, name='lam_collect')
        lam_su = tf.reshape(lam_su_flat, (NS, NU), name='lam_su')
        
        # get A and BX (summed over observations)
        # recall that X is in "long" format, and so must 
        # be handled with unsorted_segment_sum, like lambda
        A = tf.expand_dims(q_A.value(), 0) * NSU
        BX_long = tf.reduce_sum(tf.gather(B, U) * X, 1)
        BX_summed = tf.unsorted_segment_sum(BX_long, codes_SU, NS * NU)
        BX = tf.reshape(BX_summed, (NS, NU), name='BX')
        
        # lam_su * C_{uk}
        lin_piece = tf.matmul(lam_su - A - BX, C, name='linear_piece')
        
        prec = 1/tf.square(q_sig.value())
        
        z_coeff = logit_pi - prec * (0.5 * quad_piece - lin_piece)
        
        update_z_op = Zlogit.assign(z_coeff)
        
        return update_z_op

# %%
def update_pi():
    # update probabilites for features based on exact conjugate update
    with tf.variable_scope("update_pi"):
        xi = q_Z.mean()
        new_a = tf.reduce_sum(xi, 0) + a_prior
        new_b = tf.reduce_sum(1. - xi, 0) + b_prior
        update_a_op = a_var.assign(new_a)
        update_b_op = b_var.assign(new_b)
        
    return [update_a_op, update_b_op]

# %%
data = {cnt: batch_counts}
inference_lam = ed.KLqp({lam: q_lam, sig: q_sig}, 
                        data={cnt: batch_counts, 
                              Z: q_Z, pi: q_pi, 
                              A: q_A, B: q_B, C: q_C,
                              muA: q_muA, muB: q_muB, muC: q_muC,
                              sigA: q_sigA, sigB: q_sigB, sigC: q_sigC})
inference_coeffs = ed.KLqp({A: q_A, B: q_B, C: q_C, 
                            muA: q_muA, muB: q_muB, muC: q_muC,
                            sigA: q_sigA, sigB: q_sigB, sigC: q_sigC}, 
                           data={cnt: batch_counts, 
                                 lam: q_lam, sig: q_sig,
                                 Z: q_Z, pi: q_pi})

inference_latents = ed.KLqp({Z: q_Z, pi: q_pi},
                            data={cnt: batch_counts, 
                                  lam: q_lam, sig: q_sig,
                                  A: q_A, B: q_B, C: q_C,
                                  muA: q_muA, muB: q_muB, muC: q_muC,
                                  sigA: q_sigA, sigB: q_sigB, sigC: q_sigC})

# %% [markdown]
# # Notes on inference:
#
# - The `logdir` keyword specifies the place to put the log file (assuming you've instrumented the code to save events, etc.). If a subdirectory is given, pointing Tensorboard at the parent directory allows you to compare across subdirectories (runs).
#     - I'm using the `jmp/instrumented` branch of the `jmxpearson/edward` fork
# - The learning rate is a difficult tradeoff: 1e-2 drastically speeds convergence but can run into NaNs; 1e-3 (the default) is much slower.
#     - **TO DO**: Does regularizing emergence of `NaN`s help with this?
# - I'm currently using "all" the data, which appears to be faster (run-time, wise) than using minibatches. (Not entirely sure why this is, except perhaps that switching data into and out of the graph has a cost.) I've also found that minibatches need to be fairly substantial to be effective, since most variables ($\lambda$, $A$, $B$, $C$) are unit-specific (i.e., local), so unless you have several observations from that unit, convergence can be slow.
#     - Ultimately, it might speed things to have a smarter minibatch selection (i.e., all observations for a single unit) when updating the local variables.
# - I've used `n_samples` = 1, 5, 10, and 25, which all seem pretty similar after 10k iterations.
# - I've noticed no difference below in how many steps one takes along each coordinate before switching (number of inner loop iterations), either in runtime or convergence. Perhaps this matters in the final stages, but I would suspect that then it favors tighter inner loops.

# %%
# Initialize each (Edward) inference step
debug = False
inf_list = [inference_lam, inference_coeffs, inference_latents]
for inf in inf_list:
    if inf is inference_lam:
        logdir = 'data/run15'
    else:
        logdir = None
        
    inf.initialize(n_print=100, n_samples=1,  
                  logdir=logdir,
                  optimizer=tf.train.AdamOptimizer(1e-2),
                  scale={lam: N/NB, cnt: N/NB},
                  debug=debug)

# %%
init = tf.initialize_all_variables()
init.run({})

# %%
n_iter = 180000
sess = tf.get_default_session()
for _ in range(n_iter):
    for inf in inf_list:
        for _ in range(1):  # make multiple steps along each set of coords
            info_dict = inf.update()
        if inf is inference_lam:
            inf.print_progress(info_dict)
# Out:
# Iteration    1 [  0%]: Loss = 10489026560.000
# Iteration  100 [ 10%]: Loss = 1247656192.000
# Iteration  200 [ 20%]: Loss = 1509568128.000
# Iteration  300 [ 30%]: Loss = 1341107968.000
# Iteration  400 [ 40%]: Loss = 1687983872.000
# Iteration  500 [ 50%]: Loss = 731544960.000
# Iteration  600 [ 60%]: Loss = 6414104064.000
# Iteration  700 [ 70%]: Loss = 616669568.000
# Iteration  800 [ 80%]: Loss = 235156528.000
# Iteration  900 [ 90%]: Loss = 311514528.000
# Iteration 1000 [100%]: Loss = 593566400.000
# Iteration 1100 [110%]: Loss = 274862656.000
# Iteration 1200 [120%]: Loss = 569846592.000
# Iteration 1300 [130%]: Loss = 221431600.000
# Iteration 1400 [140%]: Loss = 483607200.000
# Iteration 1500 [150%]: Loss = 239528192.000
# Iteration 1600 [160%]: Loss = 355986016.000
# Iteration 1700 [170%]: Loss = 162856752.000
# Iteration 1800 [180%]: Loss = 147994656.000
# Iteration 1900 [190%]: Loss = 212523952.000
# Iteration 2000 [200%]: Loss = 124910240.000
# Iteration 2100 [210%]: Loss = 151103968.000
# Iteration 2200 [220%]: Loss = 342901600.000
# Iteration 2300 [229%]: Loss = 107412112.000
# Iteration 2400 [240%]: Loss = 61358312.000
# Iteration 2500 [250%]: Loss = 203132320.000
# Iteration 2600 [260%]: Loss = 136749744.000
# Iteration 2700 [270%]: Loss = 90071656.000
# Iteration 2800 [280%]: Loss = 136531056.000
# Iteration 2900 [290%]: Loss = 1548311424.000
# Iteration 3000 [300%]: Loss = 90876192.000
# Iteration 3100 [310%]: Loss = 103626064.000
# Iteration 3200 [320%]: Loss = 45745228.000
# Iteration 3300 [330%]: Loss = 101985248.000
# Iteration 3400 [340%]: Loss = 56750220.000
# Iteration 3500 [350%]: Loss = 62563400.000
# Iteration 3600 [360%]: Loss = 74769592.000
# Iteration 3700 [370%]: Loss = 55942572.000
# Iteration 3800 [380%]: Loss = 121542304.000
# Iteration 3900 [390%]: Loss = 84178672.000
# Iteration 4000 [400%]: Loss = 46947636.000
# Iteration 4100 [409%]: Loss = 106969360.000
# Iteration 4200 [420%]: Loss = 66298968.000
# Iteration 4300 [430%]: Loss = 190580240.000
# Iteration 4400 [440%]: Loss = 31727364.000
# Iteration 4500 [450%]: Loss = 35610804.000
# Iteration 4600 [459%]: Loss = 130786504.000
# Iteration 4700 [470%]: Loss = 22385726.000
# Iteration 4800 [480%]: Loss = 33954644.000
# Iteration 4900 [490%]: Loss = 34708264.000
# Iteration 5000 [500%]: Loss = 48508556.000
# Iteration 5100 [509%]: Loss = 39814412.000
# Iteration 5200 [520%]: Loss = 30571268.000
# Iteration 5300 [530%]: Loss = 52750224.000
# Iteration 5400 [540%]: Loss = 53299276.000
# Iteration 5500 [550%]: Loss = 21703996.000
# Iteration 5600 [560%]: Loss = 51133084.000
# Iteration 5700 [570%]: Loss = 21821324.000
# Iteration 5800 [580%]: Loss = 18506252.000
# Iteration 5900 [590%]: Loss = 33010770.000
# Iteration 6000 [600%]: Loss = 31565352.000
# Iteration 6100 [610%]: Loss = 31698096.000
# Iteration 6200 [620%]: Loss = 105698376.000
# Iteration 6300 [630%]: Loss = 14341949.000
# Iteration 6400 [640%]: Loss = 14929679.000
# Iteration 6500 [650%]: Loss = 79899384.000
# Iteration 6600 [660%]: Loss = 40201948.000
# Iteration 6700 [670%]: Loss = 38730408.000
# Iteration 6800 [680%]: Loss = 20752770.000
# Iteration 6900 [690%]: Loss = 16168031.000
# Iteration 7000 [700%]: Loss = 22013664.000
# Iteration 7100 [710%]: Loss = 15128099.000
# Iteration 7200 [720%]: Loss = 11950395.000
# Iteration 7300 [730%]: Loss = 11921372.000
# Iteration 7400 [740%]: Loss = 12387720.000
# Iteration 7500 [750%]: Loss = 18443906.000
# Iteration 7600 [760%]: Loss = 33764908.000
# Iteration 7700 [770%]: Loss = 20222760.000
# Iteration 7800 [780%]: Loss = 16078707.000
# Iteration 7900 [790%]: Loss = 15907208.000
# Iteration 8000 [800%]: Loss = 9643473.000
# Iteration 8100 [810%]: Loss = 12634585.000
# Iteration 8200 [819%]: Loss = 21371160.000
# Iteration 8300 [830%]: Loss = 8390095.000
# Iteration 8400 [840%]: Loss = 23815562.000
# Iteration 8500 [850%]: Loss = 20398460.000
# Iteration 8600 [860%]: Loss = 21127072.000
# Iteration 8700 [869%]: Loss = 7341060.000
# Iteration 8800 [880%]: Loss = 10042595.000
# Iteration 8900 [890%]: Loss = 9657902.000
# Iteration 9000 [900%]: Loss = 15862894.000
# Iteration 9100 [910%]: Loss = 54811256.000
# Iteration 9200 [919%]: Loss = 20804030.000
# Iteration 9300 [930%]: Loss = 7173883.500
# Iteration 9400 [940%]: Loss = 7000476.000
# Iteration 9500 [950%]: Loss = 6269591.500
# Iteration 9600 [960%]: Loss = 8022724.500
# Iteration 9700 [969%]: Loss = 9127658.000
# Iteration 9800 [980%]: Loss = 5549527.000
# Iteration 9900 [990%]: Loss = 12067818.000
# Iteration 10000 [1000%]: Loss = 7274278.500
# Iteration 10100 [1010%]: Loss = 4425425.000
# Iteration 10200 [1019%]: Loss = 4833901.000
# Iteration 10300 [1030%]: Loss = 8136330.500
# Iteration 10400 [1040%]: Loss = 5342970.000
# Iteration 10500 [1050%]: Loss = 6195462.000
# Iteration 10600 [1060%]: Loss = 662165056.000
# Iteration 10700 [1070%]: Loss = 5619057.000
# Iteration 10800 [1080%]: Loss = 5819473.000
# Iteration 10900 [1090%]: Loss = 6276856.500
# Iteration 11000 [1100%]: Loss = 21416156.000
# Iteration 11100 [1110%]: Loss = 3529085.000
# Iteration 11200 [1120%]: Loss = 4974870.000
# Iteration 11300 [1130%]: Loss = 5359597.500
# Iteration 11400 [1140%]: Loss = 3522840.500
# Iteration 11500 [1150%]: Loss = 17358906.000
# Iteration 11600 [1160%]: Loss = 5673667.000
# Iteration 11700 [1170%]: Loss = 3712951.500
# Iteration 11800 [1180%]: Loss = 4862915.500
# Iteration 11900 [1190%]: Loss = 4492690.500
# Iteration 12000 [1200%]: Loss = 4374961.500
# Iteration 12100 [1210%]: Loss = 4585433.000
# Iteration 12200 [1220%]: Loss = 2529033.500
# Iteration 12300 [1230%]: Loss = 4379414.000
# Iteration 12400 [1240%]: Loss = 3559766.000
# Iteration 12500 [1250%]: Loss = 9161320.000
# Iteration 12600 [1260%]: Loss = 3942921.750
# Iteration 12700 [1270%]: Loss = 5365936.500
# Iteration 12800 [1280%]: Loss = 3228662.500
# Iteration 12900 [1290%]: Loss = 2003557.750
# Iteration 13000 [1300%]: Loss = 2641923.750
# Iteration 13100 [1310%]: Loss = 2967819.000
# Iteration 13200 [1320%]: Loss = 4227319.500
# Iteration 13300 [1330%]: Loss = 2380918.250
# Iteration 13400 [1340%]: Loss = 2238393.250
# Iteration 13500 [1350%]: Loss = 2546423.500
# Iteration 13600 [1360%]: Loss = 3311779.250
# Iteration 13700 [1370%]: Loss = 4759018.500
# Iteration 13800 [1380%]: Loss = 2611346.500
# Iteration 13900 [1390%]: Loss = 2778075.000
# Iteration 14000 [1400%]: Loss = 4017792.750
# Iteration 14100 [1410%]: Loss = 1907812.625
# Iteration 14200 [1420%]: Loss = 23177952.000
# Iteration 14300 [1430%]: Loss = 2228615.000
# Iteration 14400 [1440%]: Loss = 2610510.750
# Iteration 14500 [1450%]: Loss = 2026019.250
# Iteration 14600 [1460%]: Loss = 1546040.750
# Iteration 14700 [1470%]: Loss = 2271300.000
# Iteration 14800 [1480%]: Loss = 1859874.000
# Iteration 14900 [1490%]: Loss = 2343210.500
# Iteration 15000 [1500%]: Loss = 2186931.000
# Iteration 15100 [1510%]: Loss = 1676018.250
# Iteration 15200 [1520%]: Loss = 1704654.000
# Iteration 15300 [1530%]: Loss = 1559707.875
# Iteration 15400 [1540%]: Loss = 6271727.000
# Iteration 15500 [1550%]: Loss = 1358546.125
# Iteration 15600 [1560%]: Loss = 1441931.000
# Iteration 15700 [1570%]: Loss = 1828155.625
# Iteration 15800 [1580%]: Loss = 1267087.000
# Iteration 15900 [1590%]: Loss = 1872792.500
# Iteration 16000 [1600%]: Loss = 1318252.750
# Iteration 16100 [1610%]: Loss = 2302403.000
# Iteration 16200 [1620%]: Loss = 1813507.500
# Iteration 16300 [1630%]: Loss = 1674973.500
# Iteration 16400 [1639%]: Loss = 1466513.250
# Iteration 16500 [1650%]: Loss = 4378049.000
# Iteration 16600 [1660%]: Loss = 1486182.375
# Iteration 16700 [1670%]: Loss = 1240361.750
# Iteration 16800 [1680%]: Loss = 1001852.750
# Iteration 16900 [1689%]: Loss = 1416589.750
# Iteration 17000 [1700%]: Loss = 1468099.750
# Iteration 17100 [1710%]: Loss = 1328030.375
# Iteration 17200 [1720%]: Loss = 1272877.125
# Iteration 17300 [1730%]: Loss = 1320613.625
# Iteration 17400 [1739%]: Loss = 1110751.125
# Iteration 17500 [1750%]: Loss = 1050221.875
# Iteration 17600 [1760%]: Loss = 2692118.250
# Iteration 17700 [1770%]: Loss = 1081940.750
# Iteration 17800 [1780%]: Loss = 2109823.000
# Iteration 17900 [1789%]: Loss = 1751363.125
# Iteration 18000 [1800%]: Loss = 1247254.750
# Iteration 18100 [1810%]: Loss = 6328835.000
# Iteration 18200 [1820%]: Loss = 1097490.500
# Iteration 18300 [1830%]: Loss = 1136191.250
# Iteration 18400 [1839%]: Loss = 1486051.750
# Iteration 18500 [1850%]: Loss = 889987.188
# Iteration 18600 [1860%]: Loss = 978047.875
# Iteration 18700 [1870%]: Loss = 1103445.625
# Iteration 18800 [1880%]: Loss = 862439.562
# Iteration 18900 [1889%]: Loss = 1020848.625
# Iteration 19000 [1900%]: Loss = 1002098.250
# Iteration 19100 [1910%]: Loss = 773172.125
# Iteration 19200 [1920%]: Loss = 1229807.875
# Iteration 19300 [1930%]: Loss = 906192.500
# Iteration 19400 [1939%]: Loss = 944830.250
# Iteration 19500 [1950%]: Loss = 736377.562
# Iteration 19600 [1960%]: Loss = 804417.312
# Iteration 19700 [1970%]: Loss = 818814.562
# Iteration 19800 [1980%]: Loss = 793838.938
# Iteration 19900 [1989%]: Loss = 815819.000
# Iteration 20000 [2000%]: Loss = 796003.562
# Iteration 20100 [2010%]: Loss = 1195854.500
# Iteration 20200 [2020%]: Loss = 728331.875
# Iteration 20300 [2030%]: Loss = 783518.938
# Iteration 20400 [2039%]: Loss = 751270.250
# Iteration 20500 [2050%]: Loss = 765622.000
# Iteration 20600 [2060%]: Loss = 699109.812
# Iteration 20700 [2070%]: Loss = 688464.500
# Iteration 20800 [2080%]: Loss = 743982.812
# Iteration 20900 [2090%]: Loss = 706652.000
# Iteration 21000 [2100%]: Loss = 689997.500
# Iteration 21100 [2110%]: Loss = 655213.938
# Iteration 21200 [2120%]: Loss = 659436.000
# Iteration 21300 [2130%]: Loss = 653376.688
# Iteration 21400 [2140%]: Loss = 698040.875
# Iteration 21500 [2150%]: Loss = 640900.312
# Iteration 21600 [2160%]: Loss = 766243.625
# Iteration 21700 [2170%]: Loss = 869286.438
# Iteration 21800 [2180%]: Loss = nan
# Iteration 21900 [2190%]: Loss = nan
# Iteration 22000 [2200%]: Loss = nan
# Iteration 22100 [2210%]: Loss = nan
# Iteration 22200 [2220%]: Loss = nan
# Iteration 22300 [2230%]: Loss = nan
# Iteration 22400 [2240%]: Loss = nan
# Iteration 22500 [2250%]: Loss = nan
# Iteration 22600 [2260%]: Loss = nan
# Iteration 22700 [2270%]: Loss = nan
# Iteration 22800 [2280%]: Loss = nan
# Iteration 22900 [2290%]: Loss = nan
# Iteration 23000 [2300%]: Loss = nan
# Iteration 23100 [2310%]: Loss = nan
# Iteration 23200 [2320%]: Loss = nan
# Iteration 23300 [2330%]: Loss = nan
# Iteration 23400 [2340%]: Loss = nan
# Iteration 23500 [2350%]: Loss = nan
# Iteration 23600 [2360%]: Loss = nan
# Iteration 23700 [2370%]: Loss = nan
# Iteration 23800 [2380%]: Loss = nan
# Iteration 23900 [2390%]: Loss = nan
# Iteration 24000 [2400%]: Loss = nan
# Iteration 24100 [2410%]: Loss = nan
# Iteration 24200 [2420%]: Loss = nan
# Iteration 24300 [2430%]: Loss = nan
# Iteration 24400 [2440%]: Loss = nan
# Iteration 24500 [2450%]: Loss = nan
# Iteration 24600 [2460%]: Loss = nan
# Iteration 24700 [2470%]: Loss = nan
# Iteration 24800 [2480%]: Loss = nan
# Iteration 24900 [2490%]: Loss = nan
# Iteration 25000 [2500%]: Loss = nan
# Iteration 25100 [2510%]: Loss = nan
# Iteration 25200 [2520%]: Loss = nan
# Iteration 25300 [2530%]: Loss = nan
# Iteration 25400 [2540%]: Loss = nan
# Iteration 25500 [2550%]: Loss = nan
# Iteration 25600 [2560%]: Loss = nan
# Iteration 25700 [2570%]: Loss = nan
# Iteration 25800 [2580%]: Loss = nan
# Iteration 25900 [2590%]: Loss = nan
# Iteration 26000 [2600%]: Loss = nan
# Iteration 26100 [2610%]: Loss = nan
# Iteration 26200 [2620%]: Loss = nan
# Iteration 26300 [2630%]: Loss = nan
# Iteration 26400 [2640%]: Loss = nan
# Iteration 26500 [2650%]: Loss = nan
# Iteration 26600 [2660%]: Loss = nan
# Iteration 26700 [2670%]: Loss = nan
# Iteration 26800 [2680%]: Loss = nan
# Iteration 26900 [2690%]: Loss = nan
# Iteration 27000 [2700%]: Loss = nan
# Iteration 27100 [2710%]: Loss = nan
# Iteration 27200 [2720%]: Loss = nan
# Iteration 27300 [2730%]: Loss = nan
# Iteration 27400 [2740%]: Loss = nan
# Iteration 27500 [2750%]: Loss = nan
# Iteration 27600 [2760%]: Loss = nan
# Iteration 27700 [2770%]: Loss = nan
# Iteration 27800 [2780%]: Loss = nan
# Iteration 27900 [2790%]: Loss = nan
# Iteration 28000 [2800%]: Loss = nan
# Iteration 28100 [2810%]: Loss = nan
# Iteration 28200 [2820%]: Loss = nan
# Iteration 28300 [2830%]: Loss = nan
# Iteration 28400 [2840%]: Loss = nan
# Iteration 28500 [2850%]: Loss = nan
# Iteration 28600 [2860%]: Loss = nan
# Iteration 28700 [2870%]: Loss = nan
# Iteration 28800 [2880%]: Loss = nan
# Iteration 28900 [2890%]: Loss = nan
# Iteration 29000 [2900%]: Loss = nan
# Iteration 29100 [2910%]: Loss = nan
# Iteration 29200 [2920%]: Loss = nan
# Iteration 29300 [2930%]: Loss = nan
# Iteration 29400 [2940%]: Loss = nan
# Iteration 29500 [2950%]: Loss = nan
# Iteration 29600 [2960%]: Loss = nan
# Iteration 29700 [2970%]: Loss = nan
# Iteration 29800 [2980%]: Loss = nan
# Iteration 29900 [2990%]: Loss = nan
# Iteration 30000 [3000%]: Loss = nan
# Iteration 30100 [3010%]: Loss = nan
# Iteration 30200 [3020%]: Loss = nan
# Iteration 30300 [3030%]: Loss = nan
# Iteration 30400 [3040%]: Loss = nan
# Iteration 30500 [3050%]: Loss = nan
# Iteration 30600 [3060%]: Loss = nan
# Iteration 30700 [3070%]: Loss = nan
# Iteration 30800 [3080%]: Loss = nan
# Iteration 30900 [3090%]: Loss = nan
# Iteration 31000 [3100%]: Loss = nan
# Iteration 31100 [3110%]: Loss = nan
# Iteration 31200 [3120%]: Loss = nan
# Iteration 31300 [3130%]: Loss = nan
# Iteration 31400 [3140%]: Loss = nan
# Iteration 31500 [3150%]: Loss = nan
# Iteration 31600 [3160%]: Loss = nan
# Iteration 31700 [3170%]: Loss = nan
# Iteration 31800 [3180%]: Loss = nan
# Iteration 31900 [3190%]: Loss = nan
# Iteration 32000 [3200%]: Loss = nan
# Iteration 32100 [3210%]: Loss = nan
# Iteration 32200 [3220%]: Loss = nan
# Iteration 32300 [3229%]: Loss = nan
# Iteration 32400 [3240%]: Loss = nan
# Iteration 32500 [3250%]: Loss = nan
# Iteration 32600 [3260%]: Loss = nan
# Iteration 32700 [3270%]: Loss = nan
# Iteration 32800 [3279%]: Loss = nan
# Iteration 32900 [3290%]: Loss = nan
# Iteration 33000 [3300%]: Loss = nan
# Iteration 33100 [3310%]: Loss = nan
# Iteration 33200 [3320%]: Loss = nan
# Iteration 33300 [3329%]: Loss = nan
# Iteration 33400 [3340%]: Loss = nan
# Iteration 33500 [3350%]: Loss = nan
# Iteration 33600 [3360%]: Loss = nan
# Iteration 33700 [3370%]: Loss = nan
# Iteration 33800 [3379%]: Loss = nan
# Iteration 33900 [3390%]: Loss = nan
# Iteration 34000 [3400%]: Loss = nan
# Iteration 34100 [3410%]: Loss = nan
# Iteration 34200 [3420%]: Loss = nan
# Iteration 34300 [3429%]: Loss = nan
# Iteration 34400 [3440%]: Loss = nan
# Iteration 34500 [3450%]: Loss = nan
# Iteration 34600 [3460%]: Loss = nan
# Iteration 34700 [3470%]: Loss = nan
# Iteration 34800 [3479%]: Loss = nan
# Iteration 34900 [3490%]: Loss = nan
# Iteration 35000 [3500%]: Loss = nan
# Iteration 35100 [3510%]: Loss = nan
# Iteration 35200 [3520%]: Loss = nan
# Iteration 35300 [3529%]: Loss = nan
# Iteration 35400 [3540%]: Loss = nan
# Iteration 35500 [3550%]: Loss = nan
# Iteration 35600 [3560%]: Loss = nan
# Iteration 35700 [3570%]: Loss = nan
# Iteration 35800 [3579%]: Loss = nan
# Iteration 35900 [3590%]: Loss = nan
# Iteration 36000 [3600%]: Loss = nan
# Iteration 36100 [3610%]: Loss = nan
# Iteration 36200 [3620%]: Loss = nan
# Iteration 36300 [3629%]: Loss = nan
# Iteration 36400 [3640%]: Loss = nan
# Iteration 36500 [3650%]: Loss = nan
# Iteration 36600 [3660%]: Loss = nan
# Iteration 36700 [3670%]: Loss = nan
# Iteration 36800 [3679%]: Loss = nan
# Iteration 36900 [3690%]: Loss = nan
# Iteration 37000 [3700%]: Loss = nan
# Iteration 37100 [3710%]: Loss = nan
# Iteration 37200 [3720%]: Loss = nan
# Iteration 37300 [3729%]: Loss = nan
# Iteration 37400 [3740%]: Loss = nan
# Iteration 37500 [3750%]: Loss = nan
# Iteration 37600 [3760%]: Loss = nan
# Iteration 37700 [3770%]: Loss = nan
# Iteration 37800 [3779%]: Loss = nan
# Iteration 37900 [3790%]: Loss = nan
# Iteration 38000 [3800%]: Loss = nan
# Iteration 38100 [3810%]: Loss = nan
# Iteration 38200 [3820%]: Loss = nan
# Iteration 38300 [3829%]: Loss = nan
# Iteration 38400 [3840%]: Loss = nan
# Iteration 38500 [3850%]: Loss = nan
# Iteration 38600 [3860%]: Loss = nan
# Iteration 38700 [3870%]: Loss = nan
# Iteration 38800 [3879%]: Loss = nan
# Iteration 38900 [3890%]: Loss = nan
# Iteration 39000 [3900%]: Loss = nan
# Iteration 39100 [3910%]: Loss = nan
# Iteration 39200 [3920%]: Loss = nan
# Iteration 39300 [3929%]: Loss = nan
# Iteration 39400 [3940%]: Loss = nan
# Iteration 39500 [3950%]: Loss = nan
# Iteration 39600 [3960%]: Loss = nan
# Iteration 39700 [3970%]: Loss = nan
# Iteration 39800 [3979%]: Loss = nan
# Iteration 39900 [3990%]: Loss = nan
# Iteration 40000 [4000%]: Loss = nan
# Iteration 40100 [4010%]: Loss = nan
# Iteration 40200 [4020%]: Loss = nan
# Iteration 40300 [4029%]: Loss = nan
# Iteration 40400 [4040%]: Loss = nan
# Iteration 40500 [4050%]: Loss = nan
# Iteration 40600 [4060%]: Loss = nan
# Iteration 40700 [4070%]: Loss = nan
# Iteration 40800 [4079%]: Loss = nan
# Iteration 40900 [4090%]: Loss = nan
# Iteration 41000 [4100%]: Loss = nan
# Iteration 41100 [4110%]: Loss = nan
# Iteration 41200 [4120%]: Loss = nan
# Iteration 41300 [4130%]: Loss = nan
# Iteration 41400 [4140%]: Loss = nan
# Iteration 41500 [4150%]: Loss = nan
# Iteration 41600 [4160%]: Loss = nan
# Iteration 41700 [4170%]: Loss = nan
# Iteration 41800 [4180%]: Loss = nan
# Iteration 41900 [4190%]: Loss = nan
# Iteration 42000 [4200%]: Loss = nan
# Iteration 42100 [4210%]: Loss = nan
# Iteration 42200 [4220%]: Loss = nan
# Iteration 42300 [4230%]: Loss = nan
# Iteration 42400 [4240%]: Loss = nan
# Iteration 42500 [4250%]: Loss = nan
# Iteration 42600 [4260%]: Loss = nan
# Iteration 42700 [4270%]: Loss = nan
# Iteration 42800 [4280%]: Loss = nan
# Iteration 42900 [4290%]: Loss = nan
# Iteration 43000 [4300%]: Loss = nan
# Iteration 43100 [4310%]: Loss = nan
# Iteration 43200 [4320%]: Loss = nan
# Iteration 43300 [4330%]: Loss = nan
# Iteration 43400 [4340%]: Loss = nan
# Iteration 43500 [4350%]: Loss = nan
# Iteration 43600 [4360%]: Loss = nan
# Iteration 43700 [4370%]: Loss = nan
# Iteration 43800 [4380%]: Loss = nan
# Iteration 43900 [4390%]: Loss = nan
# Iteration 44000 [4400%]: Loss = nan
# Iteration 44100 [4410%]: Loss = nan
# Iteration 44200 [4420%]: Loss = nan
# Iteration 44300 [4430%]: Loss = nan
# Iteration 44400 [4440%]: Loss = nan
# Iteration 44500 [4450%]: Loss = nan
# Iteration 44600 [4460%]: Loss = nan
# Iteration 44700 [4470%]: Loss = nan
# Iteration 44800 [4480%]: Loss = nan
# Iteration 44900 [4490%]: Loss = nan
# Iteration 45000 [4500%]: Loss = nan
# Iteration 45100 [4510%]: Loss = nan
# Iteration 45200 [4520%]: Loss = nan
# Iteration 45300 [4530%]: Loss = nan
# Iteration 45400 [4540%]: Loss = nan
# Iteration 45500 [4550%]: Loss = nan
# Iteration 45600 [4560%]: Loss = nan
# Iteration 45700 [4570%]: Loss = nan
# Iteration 45800 [4580%]: Loss = nan
# Iteration 45900 [4590%]: Loss = nan
# Iteration 46000 [4600%]: Loss = nan
# Iteration 46100 [4610%]: Loss = nan
# Iteration 46200 [4620%]: Loss = nan
# Iteration 46300 [4630%]: Loss = nan
# Iteration 46400 [4640%]: Loss = nan
# Iteration 46500 [4650%]: Loss = nan
# Iteration 46600 [4660%]: Loss = nan
# Iteration 46700 [4670%]: Loss = nan
# Iteration 46800 [4680%]: Loss = nan
# Iteration 46900 [4690%]: Loss = nan
# Iteration 47000 [4700%]: Loss = nan
# Iteration 47100 [4710%]: Loss = nan
# Iteration 47200 [4720%]: Loss = nan
# Iteration 47300 [4730%]: Loss = nan
# Iteration 47400 [4740%]: Loss = nan
# Iteration 47500 [4750%]: Loss = nan
# Iteration 47600 [4760%]: Loss = nan
# Iteration 47700 [4770%]: Loss = nan
# Iteration 47800 [4780%]: Loss = nan
# Iteration 47900 [4790%]: Loss = nan
# Iteration 48000 [4800%]: Loss = nan
# Iteration 48100 [4810%]: Loss = nan
# Iteration 48200 [4820%]: Loss = nan
# Iteration 48300 [4830%]: Loss = nan
# Iteration 48400 [4840%]: Loss = nan
# Iteration 48500 [4850%]: Loss = nan
# Iteration 48600 [4860%]: Loss = nan
# Iteration 48700 [4870%]: Loss = nan
# Iteration 48800 [4880%]: Loss = nan
# Iteration 48900 [4890%]: Loss = nan
# Iteration 49000 [4900%]: Loss = nan
# Iteration 49100 [4910%]: Loss = nan
# Iteration 49200 [4920%]: Loss = nan
# Iteration 49300 [4930%]: Loss = nan
# Iteration 49400 [4940%]: Loss = nan
# Iteration 49500 [4950%]: Loss = nan
# Iteration 49600 [4960%]: Loss = nan
# Iteration 49700 [4970%]: Loss = nan
# Iteration 49800 [4980%]: Loss = nan
# Iteration 49900 [4990%]: Loss = nan
# Iteration 50000 [5000%]: Loss = nan
# Iteration 50100 [5010%]: Loss = nan
# Iteration 50200 [5020%]: Loss = nan
# Iteration 50300 [5030%]: Loss = nan
# Iteration 50400 [5040%]: Loss = nan
# Iteration 50500 [5050%]: Loss = nan
# Iteration 50600 [5060%]: Loss = nan
# Iteration 50700 [5070%]: Loss = nan
# Iteration 50800 [5080%]: Loss = nan
# Iteration 50900 [5090%]: Loss = nan
# Iteration 51000 [5100%]: Loss = nan
# Iteration 51100 [5110%]: Loss = nan
# Iteration 51200 [5120%]: Loss = nan
# Iteration 51300 [5130%]: Loss = nan
# Iteration 51400 [5140%]: Loss = nan
# Iteration 51500 [5150%]: Loss = nan
# Iteration 51600 [5160%]: Loss = nan
# Iteration 51700 [5170%]: Loss = nan
# Iteration 51800 [5180%]: Loss = nan
# Iteration 51900 [5190%]: Loss = nan
# Iteration 52000 [5200%]: Loss = nan
# Iteration 52100 [5210%]: Loss = nan
# Iteration 52200 [5220%]: Loss = nan
# Iteration 52300 [5230%]: Loss = nan
# Iteration 52400 [5240%]: Loss = nan
# Iteration 52500 [5250%]: Loss = nan
# Iteration 52600 [5260%]: Loss = nan
# Iteration 52700 [5270%]: Loss = nan
# Iteration 52800 [5280%]: Loss = nan
# Iteration 52900 [5290%]: Loss = nan
# Iteration 53000 [5300%]: Loss = nan
# Iteration 53100 [5310%]: Loss = nan
# Iteration 53200 [5320%]: Loss = nan
# Iteration 53300 [5330%]: Loss = nan
# Iteration 53400 [5340%]: Loss = nan
# Iteration 53500 [5350%]: Loss = nan
# Iteration 53600 [5360%]: Loss = nan
# Iteration 53700 [5370%]: Loss = nan
# Iteration 53800 [5380%]: Loss = nan
# Iteration 53900 [5390%]: Loss = nan
# Iteration 54000 [5400%]: Loss = nan
# Iteration 54100 [5410%]: Loss = nan
# Iteration 54200 [5420%]: Loss = nan
# Iteration 54300 [5430%]: Loss = nan
# Iteration 54400 [5440%]: Loss = nan
# Iteration 54500 [5450%]: Loss = nan
# Iteration 54600 [5460%]: Loss = nan
# Iteration 54700 [5470%]: Loss = nan
# Iteration 54800 [5480%]: Loss = nan
# Iteration 54900 [5490%]: Loss = nan
# Iteration 55000 [5500%]: Loss = nan
# Iteration 55100 [5510%]: Loss = nan
# Iteration 55200 [5520%]: Loss = nan
# Iteration 55300 [5530%]: Loss = nan
# Iteration 55400 [5540%]: Loss = nan
# Iteration 55500 [5550%]: Loss = nan
# Iteration 55600 [5560%]: Loss = nan
# Iteration 55700 [5570%]: Loss = nan
# Iteration 55800 [5580%]: Loss = nan
# Iteration 55900 [5590%]: Loss = nan
# Iteration 56000 [5600%]: Loss = nan
# Iteration 56100 [5610%]: Loss = nan
# Iteration 56200 [5620%]: Loss = nan
# Iteration 56300 [5630%]: Loss = nan
# Iteration 56400 [5640%]: Loss = nan
# Iteration 56500 [5650%]: Loss = nan
# Iteration 56600 [5660%]: Loss = nan
# Iteration 56700 [5670%]: Loss = nan
# Iteration 56800 [5680%]: Loss = nan
# Iteration 56900 [5690%]: Loss = nan
# Iteration 57000 [5700%]: Loss = nan
# Iteration 57100 [5710%]: Loss = nan
# Iteration 57200 [5720%]: Loss = nan
# Iteration 57300 [5730%]: Loss = nan
# Iteration 57400 [5740%]: Loss = nan
# Iteration 57500 [5750%]: Loss = nan
# Iteration 57600 [5760%]: Loss = nan
# Iteration 57700 [5770%]: Loss = nan
# Iteration 57800 [5780%]: Loss = nan
# Iteration 57900 [5790%]: Loss = nan
# Iteration 58000 [5800%]: Loss = nan
# Iteration 58100 [5810%]: Loss = nan
# Iteration 58200 [5820%]: Loss = nan
# Iteration 58300 [5830%]: Loss = nan
# Iteration 58400 [5840%]: Loss = nan
# Iteration 58500 [5850%]: Loss = nan
# Iteration 58600 [5860%]: Loss = nan
# Iteration 58700 [5870%]: Loss = nan
# Iteration 58800 [5880%]: Loss = nan
# Iteration 58900 [5890%]: Loss = nan
# Iteration 59000 [5900%]: Loss = nan
# Iteration 59100 [5910%]: Loss = nan
# Iteration 59200 [5920%]: Loss = nan
# Iteration 59300 [5930%]: Loss = nan
# Iteration 59400 [5940%]: Loss = nan
# Iteration 59500 [5950%]: Loss = nan
# Iteration 59600 [5960%]: Loss = nan
# Iteration 59700 [5970%]: Loss = nan
# Iteration 59800 [5980%]: Loss = nan
# Iteration 59900 [5990%]: Loss = nan
# Iteration 60000 [6000%]: Loss = nan
# Iteration 60100 [6010%]: Loss = nan
# Iteration 60200 [6020%]: Loss = nan
# Iteration 60300 [6030%]: Loss = nan
# Iteration 60400 [6040%]: Loss = nan
# Iteration 60500 [6050%]: Loss = nan
# Iteration 60600 [6060%]: Loss = nan
# Iteration 60700 [6070%]: Loss = nan
# Iteration 60800 [6080%]: Loss = nan
# Iteration 60900 [6090%]: Loss = nan
# Iteration 61000 [6100%]: Loss = nan
# Iteration 61100 [6110%]: Loss = nan
# Iteration 61200 [6120%]: Loss = nan
# Iteration 61300 [6130%]: Loss = nan
# Iteration 61400 [6140%]: Loss = nan
# Iteration 61500 [6150%]: Loss = nan
# Iteration 61600 [6160%]: Loss = nan
# Iteration 61700 [6170%]: Loss = nan
# Iteration 61800 [6180%]: Loss = nan
# Iteration 61900 [6190%]: Loss = nan
# Iteration 62000 [6200%]: Loss = nan
# Iteration 62100 [6210%]: Loss = nan
# Iteration 62200 [6220%]: Loss = nan
# Iteration 62300 [6230%]: Loss = nan
# Iteration 62400 [6240%]: Loss = nan
# Iteration 62500 [6250%]: Loss = nan
# Iteration 62600 [6260%]: Loss = nan
# Iteration 62700 [6270%]: Loss = nan
# Iteration 62800 [6280%]: Loss = nan
# Iteration 62900 [6290%]: Loss = nan
# Iteration 63000 [6300%]: Loss = nan
# Iteration 63100 [6310%]: Loss = nan
# Iteration 63200 [6320%]: Loss = nan
# Iteration 63300 [6330%]: Loss = nan
# Iteration 63400 [6340%]: Loss = nan
# Iteration 63500 [6350%]: Loss = nan
# Iteration 63600 [6360%]: Loss = nan
# Iteration 63700 [6370%]: Loss = nan
# Iteration 63800 [6380%]: Loss = nan
# Iteration 63900 [6390%]: Loss = nan
# Iteration 64000 [6400%]: Loss = nan
# Iteration 64100 [6409%]: Loss = nan
# Iteration 64200 [6420%]: Loss = nan
# Iteration 64300 [6430%]: Loss = nan
# Iteration 64400 [6440%]: Loss = nan
# Iteration 64500 [6450%]: Loss = nan
# Iteration 64600 [6459%]: Loss = nan
# Iteration 64700 [6470%]: Loss = nan
# Iteration 64800 [6480%]: Loss = nan
# Iteration 64900 [6490%]: Loss = nan
# Iteration 65000 [6500%]: Loss = nan
# Iteration 65100 [6509%]: Loss = nan
# Iteration 65200 [6520%]: Loss = nan
# Iteration 65300 [6530%]: Loss = nan
# Iteration 65400 [6540%]: Loss = nan
# Iteration 65500 [6550%]: Loss = nan
# Iteration 65600 [6559%]: Loss = nan
# Iteration 65700 [6570%]: Loss = nan
# Iteration 65800 [6580%]: Loss = nan
# Iteration 65900 [6590%]: Loss = nan
# Iteration 66000 [6600%]: Loss = nan
# Iteration 66100 [6609%]: Loss = nan
# Iteration 66200 [6620%]: Loss = nan
# Iteration 66300 [6630%]: Loss = nan
# Iteration 66400 [6640%]: Loss = nan
# Iteration 66500 [6650%]: Loss = nan
# Iteration 66600 [6659%]: Loss = nan
# Iteration 66700 [6670%]: Loss = nan
# Iteration 66800 [6680%]: Loss = nan
# Iteration 66900 [6690%]: Loss = nan
# Iteration 67000 [6700%]: Loss = nan
# Iteration 67100 [6709%]: Loss = nan
# Iteration 67200 [6720%]: Loss = nan
# Iteration 67300 [6730%]: Loss = nan
# Iteration 67400 [6740%]: Loss = nan
# Iteration 67500 [6750%]: Loss = nan
# Iteration 67600 [6759%]: Loss = nan
# Iteration 67700 [6770%]: Loss = nan
# Iteration 67800 [6780%]: Loss = nan
# Iteration 67900 [6790%]: Loss = nan
# Iteration 68000 [6800%]: Loss = nan
# Iteration 68100 [6809%]: Loss = nan
# Iteration 68200 [6820%]: Loss = nan
# Iteration 68300 [6830%]: Loss = nan
# Iteration 68400 [6840%]: Loss = nan
# Iteration 68500 [6850%]: Loss = nan
# Iteration 68600 [6859%]: Loss = nan
# Iteration 68700 [6870%]: Loss = nan
# Iteration 68800 [6880%]: Loss = nan
# Iteration 68900 [6890%]: Loss = nan
# Iteration 69000 [6900%]: Loss = nan
# Iteration 69100 [6909%]: Loss = nan
# Iteration 69200 [6920%]: Loss = nan
# Iteration 69300 [6930%]: Loss = nan
# Iteration 69400 [6940%]: Loss = nan
# Iteration 69500 [6950%]: Loss = nan
# Iteration 69600 [6959%]: Loss = nan
# Iteration 69700 [6970%]: Loss = nan
# Iteration 69800 [6980%]: Loss = nan
# Iteration 69900 [6990%]: Loss = nan
# Iteration 70000 [7000%]: Loss = nan
# Iteration 70100 [7009%]: Loss = nan
# Iteration 70200 [7020%]: Loss = nan
# Iteration 70300 [7030%]: Loss = nan
# Iteration 70400 [7040%]: Loss = nan
# Iteration 70500 [7050%]: Loss = nan
# Iteration 70600 [7059%]: Loss = nan
# Iteration 70700 [7070%]: Loss = nan
# Iteration 70800 [7080%]: Loss = nan
# Iteration 70900 [7090%]: Loss = nan
# Iteration 71000 [7100%]: Loss = nan
# Iteration 71100 [7109%]: Loss = nan
# Iteration 71200 [7120%]: Loss = nan
# Iteration 71300 [7130%]: Loss = nan
# Iteration 71400 [7140%]: Loss = nan
# Iteration 71500 [7150%]: Loss = nan
# Iteration 71600 [7159%]: Loss = nan
# Iteration 71700 [7170%]: Loss = nan
# Iteration 71800 [7180%]: Loss = nan
# Iteration 71900 [7190%]: Loss = nan
# Iteration 72000 [7200%]: Loss = nan
# Iteration 72100 [7209%]: Loss = nan
# Iteration 72200 [7220%]: Loss = nan
# Iteration 72300 [7230%]: Loss = nan
# Iteration 72400 [7240%]: Loss = nan
# Iteration 72500 [7250%]: Loss = nan
# Iteration 72600 [7259%]: Loss = nan
# Iteration 72700 [7270%]: Loss = nan
# Iteration 72800 [7280%]: Loss = nan
# Iteration 72900 [7290%]: Loss = nan
# Iteration 73000 [7300%]: Loss = nan
# Iteration 73100 [7309%]: Loss = nan
# Iteration 73200 [7320%]: Loss = nan
# Iteration 73300 [7330%]: Loss = nan
# Iteration 73400 [7340%]: Loss = nan
# Iteration 73500 [7350%]: Loss = nan
# Iteration 73600 [7359%]: Loss = nan
# Iteration 73700 [7370%]: Loss = nan
# Iteration 73800 [7380%]: Loss = nan
# Iteration 73900 [7390%]: Loss = nan
# Iteration 74000 [7400%]: Loss = nan
# Iteration 74100 [7409%]: Loss = nan
# Iteration 74200 [7420%]: Loss = nan
# Iteration 74300 [7430%]: Loss = nan
# Iteration 74400 [7440%]: Loss = nan
# Iteration 74500 [7450%]: Loss = nan
# Iteration 74600 [7459%]: Loss = nan
# Iteration 74700 [7470%]: Loss = nan
# Iteration 74800 [7480%]: Loss = nan
# Iteration 74900 [7490%]: Loss = nan
# Iteration 75000 [7500%]: Loss = nan
# Iteration 75100 [7509%]: Loss = nan
# Iteration 75200 [7520%]: Loss = nan
# Iteration 75300 [7530%]: Loss = nan
# Iteration 75400 [7540%]: Loss = nan
# Iteration 75500 [7550%]: Loss = nan
# Iteration 75600 [7559%]: Loss = nan
# Iteration 75700 [7570%]: Loss = nan
# Iteration 75800 [7580%]: Loss = nan
# Iteration 75900 [7590%]: Loss = nan
# Iteration 76000 [7600%]: Loss = nan
# Iteration 76100 [7609%]: Loss = nan
# Iteration 76200 [7620%]: Loss = nan
# Iteration 76300 [7630%]: Loss = nan
# Iteration 76400 [7640%]: Loss = nan
# Iteration 76500 [7650%]: Loss = nan
# Iteration 76600 [7659%]: Loss = nan
# Iteration 76700 [7670%]: Loss = nan
# Iteration 76800 [7680%]: Loss = nan
# Iteration 76900 [7690%]: Loss = nan
# Iteration 77000 [7700%]: Loss = nan
# Iteration 77100 [7709%]: Loss = nan
# Iteration 77200 [7720%]: Loss = nan
# Iteration 77300 [7730%]: Loss = nan
# Iteration 77400 [7740%]: Loss = nan
# Iteration 77500 [7750%]: Loss = nan
# Iteration 77600 [7759%]: Loss = nan
# Iteration 77700 [7770%]: Loss = nan
# Iteration 77800 [7780%]: Loss = nan
# Iteration 77900 [7790%]: Loss = nan
# Iteration 78000 [7800%]: Loss = nan
# Iteration 78100 [7809%]: Loss = nan
# Iteration 78200 [7820%]: Loss = nan
# Iteration 78300 [7830%]: Loss = nan
# Iteration 78400 [7840%]: Loss = nan
# Iteration 78500 [7850%]: Loss = nan
# Iteration 78600 [7859%]: Loss = nan
# Iteration 78700 [7870%]: Loss = nan
# Iteration 78800 [7880%]: Loss = nan
# Iteration 78900 [7890%]: Loss = nan
# Iteration 79000 [7900%]: Loss = nan
# Iteration 79100 [7909%]: Loss = nan
# Iteration 79200 [7920%]: Loss = nan
# Iteration 79300 [7930%]: Loss = nan
# Iteration 79400 [7940%]: Loss = nan
# Iteration 79500 [7950%]: Loss = nan
# Iteration 79600 [7959%]: Loss = nan
# Iteration 79700 [7970%]: Loss = nan
# Iteration 79800 [7980%]: Loss = nan
# Iteration 79900 [7990%]: Loss = nan
# Iteration 80000 [8000%]: Loss = nan
# Iteration 80100 [8009%]: Loss = nan
# Iteration 80200 [8020%]: Loss = nan
# Iteration 80300 [8030%]: Loss = nan
# Iteration 80400 [8040%]: Loss = nan
# Iteration 80500 [8050%]: Loss = nan
# Iteration 80600 [8059%]: Loss = nan
# Iteration 80700 [8070%]: Loss = nan
# Iteration 80800 [8080%]: Loss = nan
# Iteration 80900 [8090%]: Loss = nan
# Iteration 81000 [8100%]: Loss = nan
# Iteration 81100 [8109%]: Loss = nan
# Iteration 81200 [8120%]: Loss = nan
# Iteration 81300 [8130%]: Loss = nan
# Iteration 81400 [8140%]: Loss = nan
# Iteration 81500 [8150%]: Loss = nan
# Iteration 81600 [8159%]: Loss = nan
# Iteration 81700 [8170%]: Loss = nan
# Iteration 81800 [8180%]: Loss = nan
# Iteration 81900 [8190%]: Loss = nan
# Iteration 82000 [8200%]: Loss = nan
# Iteration 82100 [8210%]: Loss = nan
# Iteration 82200 [8220%]: Loss = nan
# Iteration 82300 [8230%]: Loss = nan
# Iteration 82400 [8240%]: Loss = nan
# Iteration 82500 [8250%]: Loss = nan
# Iteration 82600 [8260%]: Loss = nan
# Iteration 82700 [8270%]: Loss = nan
# Iteration 82800 [8280%]: Loss = nan
# Iteration 82900 [8290%]: Loss = nan
# Iteration 83000 [8300%]: Loss = nan
# Iteration 83100 [8310%]: Loss = nan
# Iteration 83200 [8320%]: Loss = nan
# Iteration 83300 [8330%]: Loss = nan
# Iteration 83400 [8340%]: Loss = nan
# Iteration 83500 [8350%]: Loss = nan
# Iteration 83600 [8360%]: Loss = nan
# Iteration 83700 [8370%]: Loss = nan
# Iteration 83800 [8380%]: Loss = nan
# Iteration 83900 [8390%]: Loss = nan
# Iteration 84000 [8400%]: Loss = nan
# Iteration 84100 [8410%]: Loss = nan
# Iteration 84200 [8420%]: Loss = nan
# Iteration 84300 [8430%]: Loss = nan
# Iteration 84400 [8440%]: Loss = nan
# Iteration 84500 [8450%]: Loss = nan
# Iteration 84600 [8460%]: Loss = nan
# Iteration 84700 [8470%]: Loss = nan
# Iteration 84800 [8480%]: Loss = nan
# Iteration 84900 [8490%]: Loss = nan
# Iteration 85000 [8500%]: Loss = nan
# Iteration 85100 [8510%]: Loss = nan
# Iteration 85200 [8520%]: Loss = nan
# Iteration 85300 [8530%]: Loss = nan
# Iteration 85400 [8540%]: Loss = nan
# Iteration 85500 [8550%]: Loss = nan
# Iteration 85600 [8560%]: Loss = nan
# Iteration 85700 [8570%]: Loss = nan
# Iteration 85800 [8580%]: Loss = nan
# Iteration 85900 [8590%]: Loss = nan
# Iteration 86000 [8600%]: Loss = nan
# Iteration 86100 [8610%]: Loss = nan
# Iteration 86200 [8620%]: Loss = nan
# Iteration 86300 [8630%]: Loss = nan
# Iteration 86400 [8640%]: Loss = nan
# Iteration 86500 [8650%]: Loss = nan
# Iteration 86600 [8660%]: Loss = nan
# Iteration 86700 [8670%]: Loss = nan
# Iteration 86800 [8680%]: Loss = nan
# Iteration 86900 [8690%]: Loss = nan
# Iteration 87000 [8700%]: Loss = nan
# Iteration 87100 [8710%]: Loss = nan
# Iteration 87200 [8720%]: Loss = nan
# Iteration 87300 [8730%]: Loss = nan
# Iteration 87400 [8740%]: Loss = nan
# Iteration 87500 [8750%]: Loss = nan
# Iteration 87600 [8760%]: Loss = nan
# Iteration 87700 [8770%]: Loss = nan
# Iteration 87800 [8780%]: Loss = nan
# Iteration 87900 [8790%]: Loss = nan
# Iteration 88000 [8800%]: Loss = nan
# Iteration 88100 [8810%]: Loss = nan
# Iteration 88200 [8820%]: Loss = nan
# Iteration 88300 [8830%]: Loss = nan
# Iteration 88400 [8840%]: Loss = nan
# Iteration 88500 [8850%]: Loss = nan
# Iteration 88600 [8860%]: Loss = nan
# Iteration 88700 [8870%]: Loss = nan
# Iteration 88800 [8880%]: Loss = nan
# Iteration 88900 [8890%]: Loss = nan
# Iteration 89000 [8900%]: Loss = nan
# Iteration 89100 [8910%]: Loss = nan
# Iteration 89200 [8920%]: Loss = nan
# Iteration 89300 [8930%]: Loss = nan
# Iteration 89400 [8940%]: Loss = nan
# Iteration 89500 [8950%]: Loss = nan
# Iteration 89600 [8960%]: Loss = nan
# Iteration 89700 [8970%]: Loss = nan
# Iteration 89800 [8980%]: Loss = nan
# Iteration 89900 [8990%]: Loss = nan
# Iteration 90000 [9000%]: Loss = nan
# Iteration 90100 [9010%]: Loss = nan
# Iteration 90200 [9020%]: Loss = nan
# Iteration 90300 [9030%]: Loss = nan
# Iteration 90400 [9040%]: Loss = nan
# Iteration 90500 [9050%]: Loss = nan
# Iteration 90600 [9060%]: Loss = nan
# Iteration 90700 [9070%]: Loss = nan
# Iteration 90800 [9080%]: Loss = nan
# Iteration 90900 [9090%]: Loss = nan
# Iteration 91000 [9100%]: Loss = nan
# Iteration 91100 [9110%]: Loss = nan
# Iteration 91200 [9120%]: Loss = nan
# Iteration 91300 [9130%]: Loss = nan
# Iteration 91400 [9140%]: Loss = nan
# Iteration 91500 [9150%]: Loss = nan
# Iteration 91600 [9160%]: Loss = nan
# Iteration 91700 [9170%]: Loss = nan
# Iteration 91800 [9180%]: Loss = nan
# Iteration 91900 [9190%]: Loss = nan
# Iteration 92000 [9200%]: Loss = nan
# Iteration 92100 [9210%]: Loss = nan
# Iteration 92200 [9220%]: Loss = nan
# Iteration 92300 [9230%]: Loss = nan
# Iteration 92400 [9240%]: Loss = nan
# Iteration 92500 [9250%]: Loss = nan
# Iteration 92600 [9260%]: Loss = nan
# Iteration 92700 [9270%]: Loss = nan
# Iteration 92800 [9280%]: Loss = nan
# Iteration 92900 [9290%]: Loss = nan
# Iteration 93000 [9300%]: Loss = nan
# Iteration 93100 [9310%]: Loss = nan
# Iteration 93200 [9320%]: Loss = nan
# Iteration 93300 [9330%]: Loss = nan
# Iteration 93400 [9340%]: Loss = nan
# Iteration 93500 [9350%]: Loss = nan
# Iteration 93600 [9360%]: Loss = nan
# Iteration 93700 [9370%]: Loss = nan
# Iteration 93800 [9380%]: Loss = nan
# Iteration 93900 [9390%]: Loss = nan
# Iteration 94000 [9400%]: Loss = nan
# Iteration 94100 [9410%]: Loss = nan
# Iteration 94200 [9420%]: Loss = nan
# Iteration 94300 [9430%]: Loss = nan
# Iteration 94400 [9440%]: Loss = nan
# Iteration 94500 [9450%]: Loss = nan
# Iteration 94600 [9460%]: Loss = nan
# Iteration 94700 [9470%]: Loss = nan
# Iteration 94800 [9480%]: Loss = nan
# Iteration 94900 [9490%]: Loss = nan
# Iteration 95000 [9500%]: Loss = nan
# Iteration 95100 [9510%]: Loss = nan
# Iteration 95200 [9520%]: Loss = nan
# Iteration 95300 [9530%]: Loss = nan
# Iteration 95400 [9540%]: Loss = nan
# Iteration 95500 [9550%]: Loss = nan
# Iteration 95600 [9560%]: Loss = nan
# Iteration 95700 [9570%]: Loss = nan
# Iteration 95800 [9580%]: Loss = nan
# Iteration 95900 [9590%]: Loss = nan
# Iteration 96000 [9600%]: Loss = nan
# Iteration 96100 [9610%]: Loss = nan
# Iteration 96200 [9620%]: Loss = nan
# Iteration 96300 [9630%]: Loss = nan
# Iteration 96400 [9640%]: Loss = nan
# Iteration 96500 [9650%]: Loss = nan
# Iteration 96600 [9660%]: Loss = nan
# Iteration 96700 [9670%]: Loss = nan
# Iteration 96800 [9680%]: Loss = nan
# Iteration 96900 [9690%]: Loss = nan
# Iteration 97000 [9700%]: Loss = nan
# Iteration 97100 [9710%]: Loss = nan
# Iteration 97200 [9720%]: Loss = nan
# Iteration 97300 [9730%]: Loss = nan
# Iteration 97400 [9740%]: Loss = nan
# Iteration 97500 [9750%]: Loss = nan
# Iteration 97600 [9760%]: Loss = nan
# Iteration 97700 [9770%]: Loss = nan
# Iteration 97800 [9780%]: Loss = nan
# Iteration 97900 [9790%]: Loss = nan
# Iteration 98000 [9800%]: Loss = nan
# Iteration 98100 [9810%]: Loss = nan
# Iteration 98200 [9820%]: Loss = nan
# Iteration 98300 [9830%]: Loss = nan
# Iteration 98400 [9840%]: Loss = nan
# Iteration 98500 [9850%]: Loss = nan
# Iteration 98600 [9860%]: Loss = nan
# Iteration 98700 [9870%]: Loss = nan
# Iteration 98800 [9880%]: Loss = nan
# Iteration 98900 [9890%]: Loss = nan
# Iteration 99000 [9900%]: Loss = nan
# Iteration 99100 [9910%]: Loss = nan
# Iteration 99200 [9920%]: Loss = nan
# Iteration 99300 [9930%]: Loss = nan
# Iteration 99400 [9940%]: Loss = nan
# Iteration 99500 [9950%]: Loss = nan
# Iteration 99600 [9960%]: Loss = nan
# Iteration 99700 [9970%]: Loss = nan
# Iteration 99800 [9980%]: Loss = nan
# Iteration 99900 [9990%]: Loss = nan
# Iteration 100000 [10000%]: Loss = nan
# Iteration 100100 [10010%]: Loss = nan
# Iteration 100200 [10020%]: Loss = nan
# Iteration 100300 [10030%]: Loss = nan
# Iteration 100400 [10040%]: Loss = nan
# Iteration 100500 [10050%]: Loss = nan
# Iteration 100600 [10060%]: Loss = nan
# Iteration 100700 [10070%]: Loss = nan
# Iteration 100800 [10080%]: Loss = nan
# Iteration 100900 [10090%]: Loss = nan
# Iteration 101000 [10100%]: Loss = nan
# Iteration 101100 [10110%]: Loss = nan
# Iteration 101200 [10120%]: Loss = nan
# Iteration 101300 [10130%]: Loss = nan
# Iteration 101400 [10140%]: Loss = nan
# Iteration 101500 [10150%]: Loss = nan
# Iteration 101600 [10160%]: Loss = nan
# Iteration 101700 [10170%]: Loss = nan
# Iteration 101800 [10180%]: Loss = nan
# Iteration 101900 [10190%]: Loss = nan
# Iteration 102000 [10200%]: Loss = nan
# Iteration 102100 [10210%]: Loss = nan
# Iteration 102200 [10220%]: Loss = nan
# Iteration 102300 [10230%]: Loss = nan
# Iteration 102400 [10240%]: Loss = nan
# Iteration 102500 [10250%]: Loss = nan
# Iteration 102600 [10260%]: Loss = nan
# Iteration 102700 [10270%]: Loss = nan
# Iteration 102800 [10280%]: Loss = nan
# Iteration 102900 [10290%]: Loss = nan
# Iteration 103000 [10300%]: Loss = nan
# Iteration 103100 [10310%]: Loss = nan
# Iteration 103200 [10320%]: Loss = nan
# Iteration 103300 [10330%]: Loss = nan
# Iteration 103400 [10340%]: Loss = nan
# Iteration 103500 [10350%]: Loss = nan
# Iteration 103600 [10360%]: Loss = nan
# Iteration 103700 [10370%]: Loss = nan
# Iteration 103800 [10380%]: Loss = nan
# Iteration 103900 [10390%]: Loss = nan
# Iteration 104000 [10400%]: Loss = nan
# Iteration 104100 [10410%]: Loss = nan
# Iteration 104200 [10420%]: Loss = nan
# Iteration 104300 [10430%]: Loss = nan
# Iteration 104400 [10440%]: Loss = nan
# Iteration 104500 [10450%]: Loss = nan
# Iteration 104600 [10460%]: Loss = nan
# Iteration 104700 [10470%]: Loss = nan
# Iteration 104800 [10480%]: Loss = nan
# Iteration 104900 [10490%]: Loss = nan
# Iteration 105000 [10500%]: Loss = nan
# Iteration 105100 [10510%]: Loss = nan
# Iteration 105200 [10520%]: Loss = nan
# Iteration 105300 [10530%]: Loss = nan
# Iteration 105400 [10540%]: Loss = nan
# Iteration 105500 [10550%]: Loss = nan
# Iteration 105600 [10560%]: Loss = nan
# Iteration 105700 [10570%]: Loss = nan
# Iteration 105800 [10580%]: Loss = nan
# Iteration 105900 [10590%]: Loss = nan
# Iteration 106000 [10600%]: Loss = nan
# Iteration 106100 [10610%]: Loss = nan
# Iteration 106200 [10620%]: Loss = nan
# Iteration 106300 [10630%]: Loss = nan
# Iteration 106400 [10640%]: Loss = nan
# Iteration 106500 [10650%]: Loss = nan
# Iteration 106600 [10660%]: Loss = nan
# Iteration 106700 [10670%]: Loss = nan
# Iteration 106800 [10680%]: Loss = nan
# Iteration 106900 [10690%]: Loss = nan
# Iteration 107000 [10700%]: Loss = nan
# Iteration 107100 [10710%]: Loss = nan
# Iteration 107200 [10720%]: Loss = nan
# Iteration 107300 [10730%]: Loss = nan
# Iteration 107400 [10740%]: Loss = nan
# Iteration 107500 [10750%]: Loss = nan
# Iteration 107600 [10760%]: Loss = nan
# Iteration 107700 [10770%]: Loss = nan
# Iteration 107800 [10780%]: Loss = nan
# Iteration 107900 [10790%]: Loss = nan
# Iteration 108000 [10800%]: Loss = nan
# Iteration 108100 [10810%]: Loss = nan
# Iteration 108200 [10820%]: Loss = nan
# Iteration 108300 [10830%]: Loss = nan
# Iteration 108400 [10840%]: Loss = nan
# Iteration 108500 [10850%]: Loss = nan
# Iteration 108600 [10860%]: Loss = nan
# Iteration 108700 [10870%]: Loss = nan
# Iteration 108800 [10880%]: Loss = nan
# Iteration 108900 [10890%]: Loss = nan
# Iteration 109000 [10900%]: Loss = nan
# Iteration 109100 [10910%]: Loss = nan
# Iteration 109200 [10920%]: Loss = nan
# Iteration 109300 [10930%]: Loss = nan
# Iteration 109400 [10940%]: Loss = nan
# Iteration 109500 [10950%]: Loss = nan
# Iteration 109600 [10960%]: Loss = nan
# Iteration 109700 [10970%]: Loss = nan
# Iteration 109800 [10980%]: Loss = nan
# Iteration 109900 [10990%]: Loss = nan
# Iteration 110000 [11000%]: Loss = nan
# Iteration 110100 [11010%]: Loss = nan
# Iteration 110200 [11020%]: Loss = nan
# Iteration 110300 [11030%]: Loss = nan
# Iteration 110400 [11040%]: Loss = nan
# Iteration 110500 [11050%]: Loss = nan
# Iteration 110600 [11060%]: Loss = nan
# Iteration 110700 [11070%]: Loss = nan
# Iteration 110800 [11080%]: Loss = nan
# Iteration 110900 [11090%]: Loss = nan
# Iteration 111000 [11100%]: Loss = nan
# Iteration 111100 [11110%]: Loss = nan
# Iteration 111200 [11120%]: Loss = nan
# Iteration 111300 [11130%]: Loss = nan
# Iteration 111400 [11140%]: Loss = nan
# Iteration 111500 [11150%]: Loss = nan
# Iteration 111600 [11160%]: Loss = nan
# Iteration 111700 [11170%]: Loss = nan
# Iteration 111800 [11180%]: Loss = nan
# Iteration 111900 [11190%]: Loss = nan
# Iteration 112000 [11200%]: Loss = nan
# Iteration 112100 [11210%]: Loss = nan
# Iteration 112200 [11220%]: Loss = nan
# Iteration 112300 [11230%]: Loss = nan
# Iteration 112400 [11240%]: Loss = nan
# Iteration 112500 [11250%]: Loss = nan
# Iteration 112600 [11260%]: Loss = nan
# Iteration 112700 [11270%]: Loss = nan
# Iteration 112800 [11280%]: Loss = nan
# Iteration 112900 [11290%]: Loss = nan
# Iteration 113000 [11300%]: Loss = nan
# Iteration 113100 [11310%]: Loss = nan
# Iteration 113200 [11320%]: Loss = nan
# Iteration 113300 [11330%]: Loss = nan
# Iteration 113400 [11340%]: Loss = nan
# Iteration 113500 [11350%]: Loss = nan
# Iteration 113600 [11360%]: Loss = nan
# Iteration 113700 [11370%]: Loss = nan
# Iteration 113800 [11380%]: Loss = nan
# Iteration 113900 [11390%]: Loss = nan
# Iteration 114000 [11400%]: Loss = nan
# Iteration 114100 [11410%]: Loss = nan
# Iteration 114200 [11420%]: Loss = nan
# Iteration 114300 [11430%]: Loss = nan
# Iteration 114400 [11440%]: Loss = nan
# Iteration 114500 [11450%]: Loss = nan
# Iteration 114600 [11460%]: Loss = nan
# Iteration 114700 [11470%]: Loss = nan
# Iteration 114800 [11480%]: Loss = nan
# Iteration 114900 [11490%]: Loss = nan
# Iteration 115000 [11500%]: Loss = nan
# Iteration 115100 [11510%]: Loss = nan
# Iteration 115200 [11520%]: Loss = nan
# Iteration 115300 [11530%]: Loss = nan
# Iteration 115400 [11540%]: Loss = nan
# Iteration 115500 [11550%]: Loss = nan
# Iteration 115600 [11560%]: Loss = nan
# Iteration 115700 [11570%]: Loss = nan
# Iteration 115800 [11580%]: Loss = nan
# Iteration 115900 [11590%]: Loss = nan
# Iteration 116000 [11600%]: Loss = nan
# Iteration 116100 [11610%]: Loss = nan
# Iteration 116200 [11620%]: Loss = nan
# Iteration 116300 [11630%]: Loss = nan
# Iteration 116400 [11640%]: Loss = nan
# Iteration 116500 [11650%]: Loss = nan
# Iteration 116600 [11660%]: Loss = nan
# Iteration 116700 [11670%]: Loss = nan
# Iteration 116800 [11680%]: Loss = nan
# Iteration 116900 [11690%]: Loss = nan
# Iteration 117000 [11700%]: Loss = nan
# Iteration 117100 [11710%]: Loss = nan
# Iteration 117200 [11720%]: Loss = nan
# Iteration 117300 [11730%]: Loss = nan
# Iteration 117400 [11740%]: Loss = nan
# Iteration 117500 [11750%]: Loss = nan
# Iteration 117600 [11760%]: Loss = nan
# Iteration 117700 [11770%]: Loss = nan
# Iteration 117800 [11780%]: Loss = nan
# Iteration 117900 [11790%]: Loss = nan
# Iteration 118000 [11800%]: Loss = nan
# Iteration 118100 [11810%]: Loss = nan
# Iteration 118200 [11820%]: Loss = nan
# Iteration 118300 [11830%]: Loss = nan
# Iteration 118400 [11840%]: Loss = nan
# Iteration 118500 [11850%]: Loss = nan
# Iteration 118600 [11860%]: Loss = nan
# Iteration 118700 [11870%]: Loss = nan
# Iteration 118800 [11880%]: Loss = nan
# Iteration 118900 [11890%]: Loss = nan
# Iteration 119000 [11900%]: Loss = nan
# Iteration 119100 [11910%]: Loss = nan
# Iteration 119200 [11920%]: Loss = nan
# Iteration 119300 [11930%]: Loss = nan
# Iteration 119400 [11940%]: Loss = nan
# Iteration 119500 [11950%]: Loss = nan
# Iteration 119600 [11960%]: Loss = nan
# Iteration 119700 [11970%]: Loss = nan
# Iteration 119800 [11980%]: Loss = nan
# Iteration 119900 [11990%]: Loss = nan
# Iteration 120000 [12000%]: Loss = nan
# Iteration 120100 [12010%]: Loss = nan
# Iteration 120200 [12020%]: Loss = nan
# Iteration 120300 [12030%]: Loss = nan
# Iteration 120400 [12040%]: Loss = nan
# Iteration 120500 [12050%]: Loss = nan
# Iteration 120600 [12060%]: Loss = nan
# Iteration 120700 [12070%]: Loss = nan
# Iteration 120800 [12080%]: Loss = nan
# Iteration 120900 [12090%]: Loss = nan
# Iteration 121000 [12100%]: Loss = nan
# Iteration 121100 [12110%]: Loss = nan
# Iteration 121200 [12120%]: Loss = nan
# Iteration 121300 [12130%]: Loss = nan
# Iteration 121400 [12140%]: Loss = nan
# Iteration 121500 [12150%]: Loss = nan
# Iteration 121600 [12160%]: Loss = nan
# Iteration 121700 [12170%]: Loss = nan
# Iteration 121800 [12180%]: Loss = nan
# Iteration 121900 [12190%]: Loss = nan
# Iteration 122000 [12200%]: Loss = nan
# Iteration 122100 [12210%]: Loss = nan
# Iteration 122200 [12220%]: Loss = nan
# Iteration 122300 [12230%]: Loss = nan
# Iteration 122400 [12240%]: Loss = nan
# Iteration 122500 [12250%]: Loss = nan
# Iteration 122600 [12260%]: Loss = nan
# Iteration 122700 [12270%]: Loss = nan
# Iteration 122800 [12280%]: Loss = nan
# Iteration 122900 [12290%]: Loss = nan
# Iteration 123000 [12300%]: Loss = nan
# Iteration 123100 [12310%]: Loss = nan
# Iteration 123200 [12320%]: Loss = nan
# Iteration 123300 [12330%]: Loss = nan
# Iteration 123400 [12340%]: Loss = nan
# Iteration 123500 [12350%]: Loss = nan
# Iteration 123600 [12360%]: Loss = nan
# Iteration 123700 [12370%]: Loss = nan
# Iteration 123800 [12380%]: Loss = nan
# Iteration 123900 [12390%]: Loss = nan
# Iteration 124000 [12400%]: Loss = nan
# Iteration 124100 [12410%]: Loss = nan
# Iteration 124200 [12420%]: Loss = nan
# Iteration 124300 [12430%]: Loss = nan
# Iteration 124400 [12440%]: Loss = nan
# Iteration 124500 [12450%]: Loss = nan
# Iteration 124600 [12460%]: Loss = nan
# Iteration 124700 [12470%]: Loss = nan
# Iteration 124800 [12480%]: Loss = nan
# Iteration 124900 [12490%]: Loss = nan
# Iteration 125000 [12500%]: Loss = nan
# Iteration 125100 [12510%]: Loss = nan
# Iteration 125200 [12520%]: Loss = nan
# Iteration 125300 [12530%]: Loss = nan
# Iteration 125400 [12540%]: Loss = nan
# Iteration 125500 [12550%]: Loss = nan
# Iteration 125600 [12560%]: Loss = nan
# Iteration 125700 [12570%]: Loss = nan
# Iteration 125800 [12580%]: Loss = nan
# Iteration 125900 [12590%]: Loss = nan
# Iteration 126000 [12600%]: Loss = nan
# Iteration 126100 [12610%]: Loss = nan
# Iteration 126200 [12620%]: Loss = nan
# Iteration 126300 [12630%]: Loss = nan
# Iteration 126400 [12640%]: Loss = nan
# Iteration 126500 [12650%]: Loss = nan
# Iteration 126600 [12660%]: Loss = nan
# Iteration 126700 [12670%]: Loss = nan
# Iteration 126800 [12680%]: Loss = nan
# Iteration 126900 [12690%]: Loss = nan
# Iteration 127000 [12700%]: Loss = nan
# Iteration 127100 [12710%]: Loss = nan
# ...
# Iteration 138000 [13800%]: Loss = nan
# Iteration 138100 [13810%]: Loss = nan
# Iteration 138200 [13819%]: Loss = nan
# Iteration 138300 [13830%]: Loss = nan
# Iteration 138400 [13840%]: Loss = nan
# Iteration 138500 [13850%]: Loss = nan
# Iteration 138600 [13860%]: Loss = nan
# Iteration 138700 [13869%]: Loss = nan
# Iteration 138800 [13880%]: Loss = nan
# Iteration 138900 [13890%]: Loss = nan
# Iteration 139000 [13900%]: Loss = nan
# Iteration 139100 [13910%]: Loss = nan
# Iteration 139200 [13919%]: Loss = nan
# Iteration 139300 [13930%]: Loss = nan
# Iteration 139400 [13940%]: Loss = nan
# Iteration 139500 [13950%]: Loss = nan
# Iteration 139600 [13960%]: Loss = nan
# Iteration 139700 [13969%]: Loss = nan
# Iteration 139800 [13980%]: Loss = nan
# Iteration 139900 [13990%]: Loss = nan
# Iteration 140000 [14000%]: Loss = nan
# Iteration 140100 [14010%]: Loss = nan
# Iteration 140200 [14019%]: Loss = nan
# Iteration 140300 [14030%]: Loss = nan
# Iteration 140400 [14040%]: Loss = nan
# Iteration 140500 [14050%]: Loss = nan
# Iteration 140600 [14060%]: Loss = nan
# Iteration 140700 [14069%]: Loss = nan
# Iteration 140800 [14080%]: Loss = nan
# Iteration 140900 [14090%]: Loss = nan
# Iteration 141000 [14100%]: Loss = nan
# Iteration 141100 [14110%]: Loss = nan
# Iteration 141200 [14119%]: Loss = nan
# Iteration 141300 [14130%]: Loss = nan
# Iteration 141400 [14140%]: Loss = nan
# Iteration 141500 [14150%]: Loss = nan
# Iteration 141600 [14160%]: Loss = nan
# Iteration 141700 [14169%]: Loss = nan
# Iteration 141800 [14180%]: Loss = nan
# Iteration 141900 [14190%]: Loss = nan
# Iteration 142000 [14200%]: Loss = nan
# Iteration 142100 [14210%]: Loss = nan
# Iteration 142200 [14219%]: Loss = nan
# Iteration 142300 [14230%]: Loss = nan
# Iteration 142400 [14240%]: Loss = nan
# Iteration 142500 [14250%]: Loss = nan
# Iteration 142600 [14260%]: Loss = nan
# Iteration 142700 [14269%]: Loss = nan
# Iteration 142800 [14280%]: Loss = nan
# Iteration 142900 [14290%]: Loss = nan
# Iteration 143000 [14300%]: Loss = nan
# Iteration 143100 [14310%]: Loss = nan
# Iteration 143200 [14319%]: Loss = nan
# Iteration 143300 [14330%]: Loss = nan
# Iteration 143400 [14340%]: Loss = nan
# Iteration 143500 [14350%]: Loss = nan
# Iteration 143600 [14360%]: Loss = nan
# Iteration 143700 [14369%]: Loss = nan
# Iteration 143800 [14380%]: Loss = nan
# Iteration 143900 [14390%]: Loss = nan
# Iteration 144000 [14400%]: Loss = nan
# Iteration 144100 [14410%]: Loss = nan
# Iteration 144200 [14419%]: Loss = nan
# Iteration 144300 [14430%]: Loss = nan
# Iteration 144400 [14440%]: Loss = nan
# Iteration 144500 [14450%]: Loss = nan
# Iteration 144600 [14460%]: Loss = nan
# Iteration 144700 [14469%]: Loss = nan
# Iteration 144800 [14480%]: Loss = nan
# Iteration 144900 [14490%]: Loss = nan
# Iteration 145000 [14500%]: Loss = nan
# Iteration 145100 [14510%]: Loss = nan
# Iteration 145200 [14519%]: Loss = nan
# Iteration 145300 [14530%]: Loss = nan
# Iteration 145400 [14540%]: Loss = nan
# Iteration 145500 [14550%]: Loss = nan
# Iteration 145600 [14560%]: Loss = nan
# Iteration 145700 [14569%]: Loss = nan
# Iteration 145800 [14580%]: Loss = nan
# Iteration 145900 [14590%]: Loss = nan
# Iteration 146000 [14600%]: Loss = nan
# Iteration 146100 [14610%]: Loss = nan
# Iteration 146200 [14619%]: Loss = nan
# Iteration 146300 [14630%]: Loss = nan
# Iteration 146400 [14640%]: Loss = nan
# Iteration 146500 [14650%]: Loss = nan
# Iteration 146600 [14660%]: Loss = nan
# Iteration 146700 [14669%]: Loss = nan
# Iteration 146800 [14680%]: Loss = nan
# Iteration 146900 [14690%]: Loss = nan
# Iteration 147000 [14700%]: Loss = nan
# Iteration 147100 [14710%]: Loss = nan
# Iteration 147200 [14719%]: Loss = nan
# Iteration 147300 [14730%]: Loss = nan
# Iteration 147400 [14740%]: Loss = nan
# Iteration 147500 [14750%]: Loss = nan
# Iteration 147600 [14760%]: Loss = nan
# Iteration 147700 [14769%]: Loss = nan
# Iteration 147800 [14780%]: Loss = nan
# Iteration 147900 [14790%]: Loss = nan
# Iteration 148000 [14800%]: Loss = nan
# Iteration 148100 [14810%]: Loss = nan
# Iteration 148200 [14819%]: Loss = nan
# Iteration 148300 [14830%]: Loss = nan
# Iteration 148400 [14840%]: Loss = nan
# Iteration 148500 [14850%]: Loss = nan
# Iteration 148600 [14860%]: Loss = nan
# Iteration 148700 [14869%]: Loss = nan
# Iteration 148800 [14880%]: Loss = nan
# Iteration 148900 [14890%]: Loss = nan
# Iteration 149000 [14900%]: Loss = nan
# Iteration 149100 [14910%]: Loss = nan
# Iteration 149200 [14919%]: Loss = nan
# Iteration 149300 [14930%]: Loss = nan
# Iteration 149400 [14940%]: Loss = nan
# Iteration 149500 [14950%]: Loss = nan
# Iteration 149600 [14960%]: Loss = nan
# Iteration 149700 [14969%]: Loss = nan
# Iteration 149800 [14980%]: Loss = nan
# Iteration 149900 [14990%]: Loss = nan
# Iteration 150000 [15000%]: Loss = nan
# Iteration 150100 [15010%]: Loss = nan
# Iteration 150200 [15019%]: Loss = nan
# Iteration 150300 [15030%]: Loss = nan
# Iteration 150400 [15040%]: Loss = nan
# Iteration 150500 [15050%]: Loss = nan
# Iteration 150600 [15060%]: Loss = nan
# Iteration 150700 [15069%]: Loss = nan
# Iteration 150800 [15080%]: Loss = nan
# Iteration 150900 [15090%]: Loss = nan
# Iteration 151000 [15100%]: Loss = nan
# Iteration 151100 [15110%]: Loss = nan
# Iteration 151200 [15119%]: Loss = nan
# Iteration 151300 [15130%]: Loss = nan
# Iteration 151400 [15140%]: Loss = nan
# Iteration 151500 [15150%]: Loss = nan
# Iteration 151600 [15160%]: Loss = nan
# Iteration 151700 [15169%]: Loss = nan
# Iteration 151800 [15180%]: Loss = nan
# Iteration 151900 [15190%]: Loss = nan
# Iteration 152000 [15200%]: Loss = nan
# Iteration 152100 [15210%]: Loss = nan
# Iteration 152200 [15219%]: Loss = nan
# Iteration 152300 [15230%]: Loss = nan
# Iteration 152400 [15240%]: Loss = nan
# Iteration 152500 [15250%]: Loss = nan
# Iteration 152600 [15260%]: Loss = nan
# Iteration 152700 [15269%]: Loss = nan
# Iteration 152800 [15280%]: Loss = nan
# Iteration 152900 [15290%]: Loss = nan
# Iteration 153000 [15300%]: Loss = nan
# Iteration 153100 [15310%]: Loss = nan
# Iteration 153200 [15319%]: Loss = nan
# Iteration 153300 [15330%]: Loss = nan
# Iteration 153400 [15340%]: Loss = nan
# Iteration 153500 [15350%]: Loss = nan
# Iteration 153600 [15360%]: Loss = nan
# Iteration 153700 [15369%]: Loss = nan
# Iteration 153800 [15380%]: Loss = nan
# Iteration 153900 [15390%]: Loss = nan
# Iteration 154000 [15400%]: Loss = nan
# Iteration 154100 [15410%]: Loss = nan
# Iteration 154200 [15419%]: Loss = nan
# Iteration 154300 [15430%]: Loss = nan
# Iteration 154400 [15440%]: Loss = nan
# Iteration 154500 [15450%]: Loss = nan
# Iteration 154600 [15460%]: Loss = nan
# Iteration 154700 [15469%]: Loss = nan
# Iteration 154800 [15480%]: Loss = nan
# Iteration 154900 [15490%]: Loss = nan
# Iteration 155000 [15500%]: Loss = nan
# Iteration 155100 [15510%]: Loss = nan
# Iteration 155200 [15519%]: Loss = nan
# Iteration 155300 [15530%]: Loss = nan
# Iteration 155400 [15540%]: Loss = nan
# Iteration 155500 [15550%]: Loss = nan
# Iteration 155600 [15560%]: Loss = nan
# Iteration 155700 [15569%]: Loss = nan
# Iteration 155800 [15580%]: Loss = nan
# Iteration 155900 [15590%]: Loss = nan
# Iteration 156000 [15600%]: Loss = nan
# Iteration 156100 [15610%]: Loss = nan
# Iteration 156200 [15619%]: Loss = nan
# Iteration 156300 [15630%]: Loss = nan
# Iteration 156400 [15640%]: Loss = nan
# Iteration 156500 [15650%]: Loss = nan
# Iteration 156600 [15660%]: Loss = nan
# Iteration 156700 [15669%]: Loss = nan
# Iteration 156800 [15680%]: Loss = nan
# Iteration 156900 [15690%]: Loss = nan
# Iteration 157000 [15700%]: Loss = nan
# Iteration 157100 [15710%]: Loss = nan
# Iteration 157200 [15719%]: Loss = nan
# Iteration 157300 [15730%]: Loss = nan
# Iteration 157400 [15740%]: Loss = nan
# Iteration 157500 [15750%]: Loss = nan
# Iteration 157600 [15760%]: Loss = nan
# Iteration 157700 [15769%]: Loss = nan
# Iteration 157800 [15780%]: Loss = nan
# Iteration 157900 [15790%]: Loss = nan
# Iteration 158000 [15800%]: Loss = nan
# Iteration 158100 [15810%]: Loss = nan
# Iteration 158200 [15819%]: Loss = nan
# Iteration 158300 [15830%]: Loss = nan
# Iteration 158400 [15840%]: Loss = nan
# Iteration 158500 [15850%]: Loss = nan
# Iteration 158600 [15860%]: Loss = nan
# Iteration 158700 [15869%]: Loss = nan
# Iteration 158800 [15880%]: Loss = nan
# Iteration 158900 [15890%]: Loss = nan
# Iteration 159000 [15900%]: Loss = nan
# Iteration 159100 [15910%]: Loss = nan
# Iteration 159200 [15919%]: Loss = nan
# Iteration 159300 [15930%]: Loss = nan
# Iteration 159400 [15940%]: Loss = nan
# Iteration 159500 [15950%]: Loss = nan
# Iteration 159600 [15960%]: Loss = nan
# Iteration 159700 [15969%]: Loss = nan
# Iteration 159800 [15980%]: Loss = nan
# Iteration 159900 [15990%]: Loss = nan
# Iteration 160000 [16000%]: Loss = nan
# Iteration 160100 [16010%]: Loss = nan
# Iteration 160200 [16019%]: Loss = nan
# Iteration 160300 [16030%]: Loss = nan
# Iteration 160400 [16040%]: Loss = nan
# Iteration 160500 [16050%]: Loss = nan
# Iteration 160600 [16060%]: Loss = nan
# Iteration 160700 [16069%]: Loss = nan
# Iteration 160800 [16080%]: Loss = nan
# Iteration 160900 [16090%]: Loss = nan
# Iteration 161000 [16100%]: Loss = nan
# Iteration 161100 [16110%]: Loss = nan
# Iteration 161200 [16119%]: Loss = nan
# Iteration 161300 [16130%]: Loss = nan
# Iteration 161400 [16140%]: Loss = nan
# Iteration 161500 [16150%]: Loss = nan
# Iteration 161600 [16160%]: Loss = nan
# Iteration 161700 [16169%]: Loss = nan
# Iteration 161800 [16180%]: Loss = nan
# Iteration 161900 [16190%]: Loss = nan
# Iteration 162000 [16200%]: Loss = nan
# Iteration 162100 [16210%]: Loss = nan
# Iteration 162200 [16219%]: Loss = nan
# Iteration 162300 [16230%]: Loss = nan
# Iteration 162400 [16240%]: Loss = nan
# Iteration 162500 [16250%]: Loss = nan
# Iteration 162600 [16260%]: Loss = nan
# Iteration 162700 [16269%]: Loss = nan
# Iteration 162800 [16280%]: Loss = nan
# Iteration 162900 [16290%]: Loss = nan
# Iteration 163000 [16300%]: Loss = nan
# Iteration 163100 [16310%]: Loss = nan
# Iteration 163200 [16319%]: Loss = nan
# Iteration 163300 [16330%]: Loss = nan
# Iteration 163400 [16340%]: Loss = nan
# Iteration 163500 [16350%]: Loss = nan
# Iteration 163600 [16360%]: Loss = nan
# Iteration 163700 [16369%]: Loss = nan
# Iteration 163800 [16380%]: Loss = nan
# Iteration 163900 [16390%]: Loss = nan
# Iteration 164000 [16400%]: Loss = nan
# Iteration 164100 [16410%]: Loss = nan
# Iteration 164200 [16420%]: Loss = nan
# Iteration 164300 [16430%]: Loss = nan
# Iteration 164400 [16440%]: Loss = nan
# Iteration 164500 [16450%]: Loss = nan
# Iteration 164600 [16460%]: Loss = nan
# Iteration 164700 [16470%]: Loss = nan
# Iteration 164800 [16480%]: Loss = nan
# Iteration 164900 [16490%]: Loss = nan
# Iteration 165000 [16500%]: Loss = nan
# Iteration 165100 [16510%]: Loss = nan
# Iteration 165200 [16520%]: Loss = nan
# Iteration 165300 [16530%]: Loss = nan
# Iteration 165400 [16540%]: Loss = nan
# Iteration 165500 [16550%]: Loss = nan
# Iteration 165600 [16560%]: Loss = nan
# Iteration 165700 [16570%]: Loss = nan
# Iteration 165800 [16580%]: Loss = nan
# Iteration 165900 [16590%]: Loss = nan
# Iteration 166000 [16600%]: Loss = nan
# Iteration 166100 [16610%]: Loss = nan
# Iteration 166200 [16620%]: Loss = nan
# Iteration 166300 [16630%]: Loss = nan
# Iteration 166400 [16640%]: Loss = nan
# Iteration 166500 [16650%]: Loss = nan
# Iteration 166600 [16660%]: Loss = nan
# Iteration 166700 [16670%]: Loss = nan
# Iteration 166800 [16680%]: Loss = nan
# Iteration 166900 [16690%]: Loss = nan
# Iteration 167000 [16700%]: Loss = nan
# Iteration 167100 [16710%]: Loss = nan
# Iteration 167200 [16720%]: Loss = nan
# Iteration 167300 [16730%]: Loss = nan
# Iteration 167400 [16740%]: Loss = nan
# Iteration 167500 [16750%]: Loss = nan
# Iteration 167600 [16760%]: Loss = nan
# Iteration 167700 [16770%]: Loss = nan
# Iteration 167800 [16780%]: Loss = nan
# Iteration 167900 [16790%]: Loss = nan
# Iteration 168000 [16800%]: Loss = nan
# Iteration 168100 [16810%]: Loss = nan
# Iteration 168200 [16820%]: Loss = nan
# Iteration 168300 [16830%]: Loss = nan
# Iteration 168400 [16840%]: Loss = nan
# Iteration 168500 [16850%]: Loss = nan
# Iteration 168600 [16860%]: Loss = nan
# Iteration 168700 [16870%]: Loss = nan
# Iteration 168800 [16880%]: Loss = nan
# Iteration 168900 [16890%]: Loss = nan
# Iteration 169000 [16900%]: Loss = nan
# Iteration 169100 [16910%]: Loss = nan
# Iteration 169200 [16920%]: Loss = nan
# Iteration 169300 [16930%]: Loss = nan
# Iteration 169400 [16940%]: Loss = nan
# Iteration 169500 [16950%]: Loss = nan
# Iteration 169600 [16960%]: Loss = nan
# Iteration 169700 [16970%]: Loss = nan
# Iteration 169800 [16980%]: Loss = nan
# Iteration 169900 [16990%]: Loss = nan
# Iteration 170000 [17000%]: Loss = nan
# Iteration 170100 [17010%]: Loss = nan
# Iteration 170200 [17020%]: Loss = nan
# Iteration 170300 [17030%]: Loss = nan
# Iteration 170400 [17040%]: Loss = nan
# Iteration 170500 [17050%]: Loss = nan
# Iteration 170600 [17060%]: Loss = nan
# Iteration 170700 [17070%]: Loss = nan
# Iteration 170800 [17080%]: Loss = nan
# Iteration 170900 [17090%]: Loss = nan
# Iteration 171000 [17100%]: Loss = nan
# Iteration 171100 [17110%]: Loss = nan
# Iteration 171200 [17120%]: Loss = nan
# Iteration 171300 [17130%]: Loss = nan
# Iteration 171400 [17140%]: Loss = nan
# Iteration 171500 [17150%]: Loss = nan
# Iteration 171600 [17160%]: Loss = nan
# Iteration 171700 [17170%]: Loss = nan
# Iteration 171800 [17180%]: Loss = nan
# Iteration 171900 [17190%]: Loss = nan
# Iteration 172000 [17200%]: Loss = nan
# Iteration 172100 [17210%]: Loss = nan
# Iteration 172200 [17220%]: Loss = nan
# Iteration 172300 [17230%]: Loss = nan
# Iteration 172400 [17240%]: Loss = nan
# Iteration 172500 [17250%]: Loss = nan
# Iteration 172600 [17260%]: Loss = nan
# Iteration 172700 [17270%]: Loss = nan
# Iteration 172800 [17280%]: Loss = nan
# Iteration 172900 [17290%]: Loss = nan
# Iteration 173000 [17300%]: Loss = nan
# Iteration 173100 [17310%]: Loss = nan
# Iteration 173200 [17320%]: Loss = nan
# Iteration 173300 [17330%]: Loss = nan
# Iteration 173400 [17340%]: Loss = nan
# Iteration 173500 [17350%]: Loss = nan
# Iteration 173600 [17360%]: Loss = nan
# Iteration 173700 [17370%]: Loss = nan
# Iteration 173800 [17380%]: Loss = nan
# Iteration 173900 [17390%]: Loss = nan
# Iteration 174000 [17400%]: Loss = nan
# Iteration 174100 [17410%]: Loss = nan
# Iteration 174200 [17420%]: Loss = nan
# Iteration 174300 [17430%]: Loss = nan
# Iteration 174400 [17440%]: Loss = nan
# Iteration 174500 [17450%]: Loss = nan
# Iteration 174600 [17460%]: Loss = nan
# Iteration 174700 [17470%]: Loss = nan
# Iteration 174800 [17480%]: Loss = nan
# Iteration 174900 [17490%]: Loss = nan
# Iteration 175000 [17500%]: Loss = nan
# Iteration 175100 [17510%]: Loss = nan
# Iteration 175200 [17520%]: Loss = nan
# Iteration 175300 [17530%]: Loss = nan
# Iteration 175400 [17540%]: Loss = nan
# Iteration 175500 [17550%]: Loss = nan
# Iteration 175600 [17560%]: Loss = nan
# Iteration 175700 [17570%]: Loss = nan
# Iteration 175800 [17580%]: Loss = nan
# Iteration 175900 [17590%]: Loss = nan
# Iteration 176000 [17600%]: Loss = nan
# Iteration 176100 [17610%]: Loss = nan
# Iteration 176200 [17620%]: Loss = nan
# Iteration 176300 [17630%]: Loss = nan
# Iteration 176400 [17640%]: Loss = nan
# Iteration 176500 [17650%]: Loss = nan
# Iteration 176600 [17660%]: Loss = nan
# Iteration 176700 [17670%]: Loss = nan
# Iteration 176800 [17680%]: Loss = nan
# Iteration 176900 [17690%]: Loss = nan
# Iteration 177000 [17700%]: Loss = nan
# Iteration 177100 [17710%]: Loss = nan
# Iteration 177200 [17720%]: Loss = nan
# Iteration 177300 [17730%]: Loss = nan
# Iteration 177400 [17740%]: Loss = nan
# Iteration 177500 [17750%]: Loss = nan
# Iteration 177600 [17760%]: Loss = nan
# Iteration 177700 [17770%]: Loss = nan
# Iteration 177800 [17780%]: Loss = nan
# Iteration 177900 [17790%]: Loss = nan
# Iteration 178000 [17800%]: Loss = nan
# Iteration 178100 [17810%]: Loss = nan
# Iteration 178200 [17820%]: Loss = nan
# Iteration 178300 [17830%]: Loss = nan
# Iteration 178400 [17840%]: Loss = nan
# Iteration 178500 [17850%]: Loss = nan
# Iteration 178600 [17860%]: Loss = nan
# Iteration 178700 [17870%]: Loss = nan
# Iteration 178800 [17880%]: Loss = nan
# Iteration 178900 [17890%]: Loss = nan
# Iteration 179000 [17900%]: Loss = nan
# Iteration 179100 [17910%]: Loss = nan
# Iteration 179200 [17920%]: Loss = nan
# Iteration 179300 [17930%]: Loss = nan
# Iteration 179400 [17940%]: Loss = nan
# Iteration 179500 [17950%]: Loss = nan
# Iteration 179600 [17960%]: Loss = nan
# Iteration 179700 [17970%]: Loss = nan
# Iteration 179800 [17980%]: Loss = nan
# Iteration 179900 [17990%]: Loss = nan
# Iteration 180000 [18000%]: Loss = nan

# %%
Zmat = q_Z.mean().eval()

plt.matshow(dZ, aspect='auto', cmap='gray')
plt.matshow(Zmat.T, aspect='auto', cmap='gray')
# Out:
# /Users/jmxp/anaconda/lib/python3.5/site-packages/numpy/ma/core.py:4144: UserWarning: Warning: converting a masked element to nan.
#   warnings.warn("Warning: converting a masked element to nan.")

# %%
plt.hist(q_A.mean().eval().ravel(), label='inferred'); plt.hist(dA.ravel(), label='actual'), plt.legend();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-3a77f37adb10> in <module>()
# ----> 1 plt.hist(q_A.mean().eval().ravel(), label='inferred'); plt.hist(dA.ravel(), label='actual'), plt.legend();
#
# /Users/jmxp/anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, data, **kwargs)
#    2956                       histtype=histtype, align=align, orientation=orientation,
#    2957                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2958                       stacked=stacked, data=data, **kwargs)
#    2959     finally:
#    2960         ax.hold(washold)
#
# /Users/jmxp/anaconda/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /Users/jmxp/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6008             # this will automatically overwrite bins,
#    6009             # so that each histogram uses the same bins
# -> 6010             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6011             m = m.astype(float)  # causes problems later if it's an int
#    6012             if mlast is None:
#
# /Users/jmxp/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py in histogram(a, bins, range, normed, weights, density)
#     500     if mn > mx:
#     501         raise ValueError(
# --> 502             'max must be larger than min in range parameter.')
#     503     if not np.all(np.isfinite([mn, mx])):
#     504         raise ValueError(
#
# ValueError: max must be larger than min in range parameter.

# %%
plt.hist(q_B.mean().eval().ravel(), 200, label='inferred'), plt.hist(dB.ravel(), 200, label='actual'), plt.legend();

# %%
plt.hist(q_C.mean().eval().ravel(), 200, label='inferred'), plt.hist(dC.ravel(), 200, label='actual'), plt.legend();

# %%
plt.hist(lam_mu.eval(), 200, label='inferred'), plt.hist(dlam, 200, label='actual'), plt.legend();

# %%
lam_mu.value().eval()

# %%
q_lam.mean().eval()

# %%
q_sig.mean().eval()

# %%
q_pi._value.eval()

# %%
q_pi.std().eval()

# %%
q_pi.mean().eval()

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']
